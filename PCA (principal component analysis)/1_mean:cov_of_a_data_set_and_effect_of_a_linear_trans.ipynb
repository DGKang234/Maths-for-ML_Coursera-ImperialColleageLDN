# %% [markdown]
# # Week 1: Mean/Covariance of a data set and effect of a linear transformation
#
# In this week, we are going to investigate how the mean and (co)variance of a dataset changes
# when we apply affine transformation to the dataset.

# %% [markdown]
# ## Learning objectives
# 1. Get Farmiliar with basic programming using Python and Numpy/Scipy.
# 2. Learn to appreciate implementing
#    functions to compute statistics of dataset in vectorized way.
# 3. Understand the effects of affine transformations on a dataset.
# 4. Understand the importance of testing in programming for machine learning.

# %% [markdown]
# First, let's import the packages that we will use for the week

# %%
# PACKAGE: DO NOT EDIT
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
matplotlib.style.use('fivethirtyeight')
from sklearn.datasets import fetch_olivetti_faces
import time
import timeit
# %matplotlib inline

# %% [markdown]
# Next, we are going to retrieve Olivetti faces dataset.
#
# When working with some datasets, before digging into further analysis, it is almost always
# useful to do a few things to understand your dataset. First of all, answer the following
# set of questions:
#
# 1. What is the size of your dataset?
# 2. What is the dimensionality of your data?
#
# The dataset we have are usually stored as 2D matrices, then it would be really important
# to know which dimension represents the dimension of the dataset, and which represents
# the data points in the dataset.
#
# __When you implement the functions for your assignment, make sure you read
# the docstring for what each dimension of your inputs represents the data points, and which
# represents the dimensions of the dataset!__

# %%
image_shape = (64, 64)
# Load faces data
dataset = fetch_olivetti_faces(data_home='./')
faces = dataset.data

print('Shape of the faces dataset: {}'.format(faces.shape))
print('{} data points'.format(faces.shape[0]))
# Out:
# Shape of the faces dataset: (400, 4096)
# 400 data points

# %% [markdown]
# When your dataset are images, it's a really good idea to see what they look like.
#
# One very
# convenient tool in Jupyter is the `interact` widget, which we use to visualize the images (faces). For more information on how to use interact, have a look at the documentation [here](http://ipywidgets.readthedocs.io/en/stable/examples/Using%20Interact.html).

# %%
from ipywidgets import interact

# %%
def show_face(face):
    plt.figure()
    plt.imshow(face.reshape((64, 64)), cmap='gray')
    plt.show()
#for i in faces:
#    show_face(i)

# %%
@interact(n=(0, len(faces)-1))
def display_faces(n=0):
    plt.figure()
    plt.imshow(faces[n].reshape((64, 64)), cmap='gray')
    plt.show()
# Out:
# interactive(children=(IntSlider(value=0, description='n', max=399), Output()), _dom_classes=('widget-interact'…

# %% [markdown]
# ## 1. Mean and Covariance of a Dataset

# %% [markdown]
# #### show how algorithms are working in step-by-step manner

# %% [markdown]
# # Mean

# %%
# example for testing function
X = np.array([[0., 1., 1.], 
              [1., 2., 1.]])
print(np.mean(X, axis=0)) # column average
print(np.mean(X, axis=1)) # row average
# Out:
# [0.5 1.5 1. ]
# [0.66666667 1.33333333]

# %%
def mean_naive(X):
    # mean = average (X[1, :])
    N, D = X.shape
    mean = np.zeros(D)
    
    for n in range(N):
        for i in range(D):
            mean[i] = mean[i] + X[n, i]
            print(f"mean[{i}] = mean[{i}] + X[{n, i}]")
    print()
    print(f"array[mean[1], mean[2], mean[3]]")
    mean /= N
    
    return mean

# %%
print(np.mean(X, axis=0)) # the vector that we want to get
mean_naive(X)
# Out:
# [0.5 1.5 1. ]
# mean[0] = mean[0] + X[(0, 0)]
# mean[1] = mean[1] + X[(0, 1)]
# mean[2] = mean[2] + X[(0, 2)]
# mean[0] = mean[0] + X[(1, 0)]
# mean[1] = mean[1] + X[(1, 1)]
# mean[2] = mean[2] + X[(1, 2)]
#
# array[mean[1], mean[2], mean[3]]
# array([0.5, 1.5, 1. ])

# %% [markdown]
# # Covariance

# %%
np.cov(X.T) # the vector we want to get
# Out:
# array([[0.5, 0.5, 0. ],
#        [0.5, 0.5, 0. ],
#        [0. , 0. , 0. ]])

# %%
print(X)
print()
print(X[0, :])
# Out:
# [[0. 1. 1.]
#  [1. 2. 1.]]
#
# [0. 1. 1.]

# %%
def cov_naive(X): 
    # var[D] = 1/N sum {(x - mu) @ (x - mu).T}
    N, D = X.shape
    covariance = np.zeros((D, D)) 
    
    mat = np.zeros((N, D))
    mean = mean_naive(X)
    print()

    for i in range(N):
        mat[i] = X[i,:] - mean
        print(mat[i], X[i,:], mean)
    print()
    print(mat[:, 2])
    print()
    
    for i in range(D):
        for j in range(D):
            covariance[i, j] = covariance[i, j] + mat[:,i]@mat[:,j] # mat[:, i] @ mat[:, j] is used as mat @ mat.T
            print(f"covariance[{i}, {j}] = covariance[{i}, {j}] + mat[:, {i}] @ mat[:, {j}]")
            
    return covariance/N
print(cov_naive(X))

def cov(X):
    covariance_matrix = np.cov(X, rowvar=False, bias=True) # rowvar: (false: transpose) bias: (false = sample cov, true = pop. cov)
    return covariance_matrix
print(cov(X))
# Out:
# mean[0] = mean[0] + X[(0, 0)]
# mean[1] = mean[1] + X[(0, 1)]
# mean[2] = mean[2] + X[(0, 2)]
# mean[0] = mean[0] + X[(1, 0)]
# mean[1] = mean[1] + X[(1, 1)]
# mean[2] = mean[2] + X[(1, 2)]
#
# array[mean[1], mean[2], mean[3]]
#
# [-0.5 -0.5  0. ] [0. 1. 1.] [0.5 1.5 1. ]
# [0.5 0.5 0. ] [1. 2. 1.] [0.5 1.5 1. ]
#
# [0. 0.]
#
# covariance[0, 0] = covariance[0, 0] + mat[:, 0] @ mat[:, 0]
# covariance[0, 1] = covariance[0, 1] + mat[:, 0] @ mat[:, 1]
# covariance[0, 2] = covariance[0, 2] + mat[:, 0] @ mat[:, 2]
# covariance[1, 0] = covariance[1, 0] + mat[:, 1] @ mat[:, 0]
# covariance[1, 1] = covariance[1, 1] + mat[:, 1] @ mat[:, 1]
# covariance[1, 2] = covariance[1, 2] + mat[:, 1] @ mat[:, 2]
# covariance[2, 0] = covariance[2, 0] + mat[:, 2] @ mat[:, 0]
# covariance[2, 1] = covariance[2, 1] + mat[:, 2] @ mat[:, 1]
# covariance[2, 2] = covariance[2, 2] + mat[:, 2] @ mat[:, 2]
# [[0.25 0.25 0.  ]
#  [0.25 0.25 0.  ]
#  [0.   0.   0.  ]]
# [[0.25 0.25 0.  ]
#  [0.25 0.25 0.  ]
#  [0.   0.   0.  ]]

# %%
def cov_naive(X):
    N, D = X.shape
    covariance = np.zeros((D, D))
    
    mean = np.mean(X, axis=0)                 # = mean_navie(X)
    X -= mean                                 # (x - mu)
    covariance = np.dot(X.T, X) / N    # (X.T @ X.conj) / N
    return covariance
print(cov_naive(X))

def cov(X):
    N, D = X.shape
    covariance_matrix = np.cov(X.T, bias=True)
    return covariance_matrix
print(cov(X))
# Out:
# [[0.25 0.25 0.  ]
#  [0.25 0.25 0.  ]
#  [0.   0.   0.  ]]
# [[0.25 0.25 0.  ]
#  [0.25 0.25 0.  ]
#  [0.   0.   0.  ]]

# %% [markdown]
# # to submit the project

# %%
# GRADED FUNCTION: DO NOT EDIT THIS LINE
def mean_naive(X):
    """Compute the sample mean for a dataset by iterating over the dataset.
    
    Args:
        X: `ndarray` of shape (N, D) representing the dataset. N 
        is the size of the dataset and D is the dimensionality of the dataset.
    Returns:
        mean: `ndarray` of shape (D, ), the sample mean of the dataset `X`.
    """
    # YOUR CODE HERE
    ### Uncomment and edit the code below
    #iterate over the dataset and compute the mean vector.
    N, D = X.shape
    mean = np.zeros((D,))
    for n in range(N):
        for i in range(D):
            mean[i] = mean[i] + X[n, i]
            print(f"mean[{i}] = mean[{i}] + X[{n, i}]")
    mean /= N
    return mean

def cov_naive(X):
    """Compute the sample covariance for a dataset by iterating over the dataset.
    
    Args:
        X: `ndarray` of shape (N, D) representing the dataset. N 
        is the size of the dataset and D is the dimensionality of the dataset.
    Returns:
        ndarray: ndarray with shape (D, D), the sample covariance of the dataset `X`.
    """
    # YOUR CODE HERE
    ### Uncomment and edit the code below
    N, D = X.shape
    ### Edit the code below to compute the covariance matrix by iterating over the dataset.
    covariance = np.zeros((D, D))
    ### Update covariance
    mean = np.mean(X, axis=0)
    X -= mean
    covariance = np.dot(X.T, X.conj()) / N
    ###
    return covariance

def mean(X):
    """Compute the sample mean for a dataset.
    
    Args:
        X: `ndarray` of shape (N, D) representing the dataset. N 
        is the size of the dataset and D is the dimensionality of the dataset.
    Returns:
        ndarray: ndarray with shape (D,), the sample mean of the dataset `X`.
    """
    # YOUR CODE HERE
    ## Uncomment and edit the code below
    m = np.mean(X, axis=0)
    return m

def cov(X):
    """Compute the sample covariance for a dataset.
    
    Args:
        X: `ndarray` of shape (N, D) representing the dataset. N 
        is the size of the dataset and D is the dimensionality of the dataset.
    Returns:
        ndarray: ndarray with shape (D, D), the sample covariance of the dataset `X`.
    """
    # YOUR CODE HERE
    
    # It is possible to vectorize our code for computing the covariance with matrix multiplications,
    # i.e., we do not need to explicitly
    # iterate over the entire dataset as looping in Python tends to be slow
    # We challenge you to give a vectorized implementation without using np.cov, but if you choose to use np.cov,
    # be sure to pass in bias=True.
    ### Uncomment and edit the code below
    N, D = X.shape
    ### Edit the code to compute the covariance matrix
    covariance_matrix = np.cov(X.T, bias=True)
    ### Update covariance_matrix here
  
    ###
    return covariance_matrix

# %%
from numpy.testing import assert_allclose

# Test case 1
X = np.array([[0., 1., 1.], 
              [1., 2., 1.]])
expected_mean = np.array([0.5, 1.5, 1.])
assert_allclose(mean(X), expected_mean, rtol=1e-5)

# Test case 2
X = np.array([[0., 1., 0.], 
              [2., 3., 1.]])
expected_mean = np.array([1., 2., 0.5])
assert_allclose(mean(X), expected_mean, rtol=1e-5)

# Test covariance is zero
X = np.array([[0., 1.], 
              [0., 1.]])
expected_mean = np.array([0., 1.])
assert_allclose(mean(X), expected_mean, rtol=1e-5)

### Some hidden tests below
### ...

# %%
cov(np.array([[0., 1.], 
     [1., 2.],
     [0., 1.], 
     [1., 2.]
    ]))
# Out:
# array([[0.25, 0.25],
#        [0.25, 0.25]])

# %%
from numpy.testing import assert_allclose

# Test case 1
X = np.array([[0., 1.], 
              [1., 2.],
     [0., 1.], 
     [1., 2.]])
expected_cov = np.array(
    [[0.25, 0.25],
    [0.25, 0.25]])

assert_allclose(cov(X), expected_cov, rtol=1e-5)

# Test case 2
X = np.array([[0., 1.], 
              [2., 3.]])
expected_cov = np.array(
    [[1., 1.],
    [1., 1.]])

assert_allclose(cov(X), expected_cov, rtol=1e-5)

# Test covariance is zero
X = np.array([[0., 1.], 
              [0., 1.],
              [0., 1.]])
expected_cov = np.zeros((2, 2))

assert_allclose(cov(X), expected_cov, rtol=1e-5)

### Some hidden tests below
### ...

# %% [markdown]
# With the `mean` function implemented, let's take a look at the _mean_ face of our dataset!

# %%
def mean_face(faces):
    return faces.mean(axis=0).reshape((64, 64))

plt.imshow(mean_face(faces), cmap='gray');

# %% [markdown]
# One of the advantage of writing vectorized code is speedup gained when working on larger dataset. Loops in Python
# are slow, and most of the time you want to utilise the fast native code provided by Numpy without explicitly using
# for loops. To put things into perspective, we can benchmark the two different implementation with the `%time` function
# in the following way:

# %%
# We have some HUUUGE data matrix which we want to compute its mean
X = np.random.randn(1000, 20)
# Benchmarking time for computing mean
# %time mean_naive(X)
# %time mean(X)
pass
# Out:
# mean[0] = mean[0] + X[(0, 0)]
# mean[1] = mean[1] + X[(0, 1)]
# mean[2] = mean[2] + X[(0, 2)]
# mean[3] = mean[3] + X[(0, 3)]
# mean[4] = mean[4] + X[(0, 4)]
# mean[5] = mean[5] + X[(0, 5)]
# mean[6] = mean[6] + X[(0, 6)]
# mean[7] = mean[7] + X[(0, 7)]
# mean[8] = mean[8] + X[(0, 8)]
# mean[9] = mean[9] + X[(0, 9)]
# mean[10] = mean[10] + X[(0, 10)]
# mean[11] = mean[11] + X[(0, 11)]
# mean[12] = mean[12] + X[(0, 12)]
# mean[13] = mean[13] + X[(0, 13)]
# mean[14] = mean[14] + X[(0, 14)]
# mean[15] = mean[15] + X[(0, 15)]
# mean[16] = mean[16] + X[(0, 16)]
# mean[17] = mean[17] + X[(0, 17)]
# mean[18] = mean[18] + X[(0, 18)]
# mean[19] = mean[19] + X[(0, 19)]
# mean[0] = mean[0] + X[(1, 0)]
# mean[1] = mean[1] + X[(1, 1)]
# mean[2] = mean[2] + X[(1, 2)]
# mean[3] = mean[3] + X[(1, 3)]
# mean[4] = mean[4] + X[(1, 4)]
# mean[5] = mean[5] + X[(1, 5)]
# mean[6] = mean[6] + X[(1, 6)]
# mean[7] = mean[7] + X[(1, 7)]
# mean[8] = mean[8] + X[(1, 8)]
# mean[9] = mean[9] + X[(1, 9)]
# mean[10] = mean[10] + X[(1, 10)]
# mean[11] = mean[11] + X[(1, 11)]
# mean[12] = mean[12] + X[(1, 12)]
# mean[13] = mean[13] + X[(1, 13)]
# mean[14] = mean[14] + X[(1, 14)]
# mean[15] = mean[15] + X[(1, 15)]
# mean[16] = mean[16] + X[(1, 16)]
# mean[17] = mean[17] + X[(1, 17)]
# mean[18] = mean[18] + X[(1, 18)]
# mean[19] = mean[19] + X[(1, 19)]
# mean[0] = mean[0] + X[(2, 0)]
# mean[1] = mean[1] + X[(2, 1)]
# mean[2] = mean[2] + X[(2, 2)]
# mean[3] = mean[3] + X[(2, 3)]
# mean[4] = mean[4] + X[(2, 4)]
# mean[5] = mean[5] + X[(2, 5)]
# mean[6] = mean[6] + X[(2, 6)]
# mean[7] = mean[7] + X[(2, 7)]
# mean[8] = mean[8] + X[(2, 8)]
# mean[9] = mean[9] + X[(2, 9)]
# mean[10] = mean[10] + X[(2, 10)]
# mean[11] = mean[11] + X[(2, 11)]
# mean[12] = mean[12] + X[(2, 12)]
# mean[13] = mean[13] + X[(2, 13)]
# mean[14] = mean[14] + X[(2, 14)]
# mean[15] = mean[15] + X[(2, 15)]
# mean[16] = mean[16] + X[(2, 16)]
# mean[17] = mean[17] + X[(2, 17)]
# mean[18] = mean[18] + X[(2, 18)]
# mean[19] = mean[19] + X[(2, 19)]
# mean[0] = mean[0] + X[(3, 0)]
# mean[1] = mean[1] + X[(3, 1)]
# mean[2] = mean[2] + X[(3, 2)]
# mean[3] = mean[3] + X[(3, 3)]
# mean[4] = mean[4] + X[(3, 4)]
# mean[5] = mean[5] + X[(3, 5)]
# mean[6] = mean[6] + X[(3, 6)]
# mean[7] = mean[7] + X[(3, 7)]
# mean[8] = mean[8] + X[(3, 8)]
# mean[9] = mean[9] + X[(3, 9)]
# mean[10] = mean[10] + X[(3, 10)]
# mean[11] = mean[11] + X[(3, 11)]
# mean[12] = mean[12] + X[(3, 12)]
# mean[13] = mean[13] + X[(3, 13)]
# mean[14] = mean[14] + X[(3, 14)]
# mean[15] = mean[15] + X[(3, 15)]
# mean[16] = mean[16] + X[(3, 16)]
# mean[17] = mean[17] + X[(3, 17)]
# mean[18] = mean[18] + X[(3, 18)]
# mean[19] = mean[19] + X[(3, 19)]
# mean[0] = mean[0] + X[(4, 0)]
# mean[1] = mean[1] + X[(4, 1)]
# mean[2] = mean[2] + X[(4, 2)]
# mean[3] = mean[3] + X[(4, 3)]
# mean[4] = mean[4] + X[(4, 4)]
# mean[5] = mean[5] + X[(4, 5)]
# mean[6] = mean[6] + X[(4, 6)]
# mean[7] = mean[7] + X[(4, 7)]
# mean[8] = mean[8] + X[(4, 8)]
# mean[9] = mean[9] + X[(4, 9)]
# mean[10] = mean[10] + X[(4, 10)]
# mean[11] = mean[11] + X[(4, 11)]
# mean[12] = mean[12] + X[(4, 12)]
# mean[13] = mean[13] + X[(4, 13)]
# mean[14] = mean[14] + X[(4, 14)]
# mean[15] = mean[15] + X[(4, 15)]
# mean[16] = mean[16] + X[(4, 16)]
# mean[17] = mean[17] + X[(4, 17)]
# mean[18] = mean[18] + X[(4, 18)]
# mean[19] = mean[19] + X[(4, 19)]
# mean[0] = mean[0] + X[(5, 0)]
# mean[1] = mean[1] + X[(5, 1)]
# mean[2] = mean[2] + X[(5, 2)]
# mean[3] = mean[3] + X[(5, 3)]
# mean[4] = mean[4] + X[(5, 4)]
# mean[5] = mean[5] + X[(5, 5)]
# mean[6] = mean[6] + X[(5, 6)]
# mean[7] = mean[7] + X[(5, 7)]
# mean[8] = mean[8] + X[(5, 8)]
# mean[9] = mean[9] + X[(5, 9)]
# mean[10] = mean[10] + X[(5, 10)]
# mean[11] = mean[11] + X[(5, 11)]
# mean[12] = mean[12] + X[(5, 12)]
# mean[13] = mean[13] + X[(5, 13)]
# mean[14] = mean[14] + X[(5, 14)]
# mean[15] = mean[15] + X[(5, 15)]
# mean[16] = mean[16] + X[(5, 16)]
# mean[17] = mean[17] + X[(5, 17)]
# mean[18] = mean[18] + X[(5, 18)]
# mean[19] = mean[19] + X[(5, 19)]
# mean[0] = mean[0] + X[(6, 0)]
# mean[1] = mean[1] + X[(6, 1)]
# mean[2] = mean[2] + X[(6, 2)]
# mean[3] = mean[3] + X[(6, 3)]
# mean[4] = mean[4] + X[(6, 4)]
# mean[5] = mean[5] + X[(6, 5)]
# mean[6] = mean[6] + X[(6, 6)]
# mean[7] = mean[7] + X[(6, 7)]
# mean[8] = mean[8] + X[(6, 8)]
# mean[9] = mean[9] + X[(6, 9)]
# mean[10] = mean[10] + X[(6, 10)]
# mean[11] = mean[11] + X[(6, 11)]
# mean[12] = mean[12] + X[(6, 12)]
# mean[13] = mean[13] + X[(6, 13)]
# mean[14] = mean[14] + X[(6, 14)]
# mean[15] = mean[15] + X[(6, 15)]
# mean[16] = mean[16] + X[(6, 16)]
# mean[17] = mean[17] + X[(6, 17)]
# mean[18] = mean[18] + X[(6, 18)]
# mean[19] = mean[19] + X[(6, 19)]
# mean[0] = mean[0] + X[(7, 0)]
# mean[1] = mean[1] + X[(7, 1)]
# mean[2] = mean[2] + X[(7, 2)]
# mean[3] = mean[3] + X[(7, 3)]
# mean[4] = mean[4] + X[(7, 4)]
# mean[5] = mean[5] + X[(7, 5)]
# mean[6] = mean[6] + X[(7, 6)]
# mean[7] = mean[7] + X[(7, 7)]
# mean[8] = mean[8] + X[(7, 8)]
# mean[9] = mean[9] + X[(7, 9)]
# mean[10] = mean[10] + X[(7, 10)]
# mean[11] = mean[11] + X[(7, 11)]
# mean[12] = mean[12] + X[(7, 12)]
# mean[13] = mean[13] + X[(7, 13)]
# mean[14] = mean[14] + X[(7, 14)]
# mean[15] = mean[15] + X[(7, 15)]
# mean[16] = mean[16] + X[(7, 16)]
# mean[17] = mean[17] + X[(7, 17)]
# mean[18] = mean[18] + X[(7, 18)]
# mean[19] = mean[19] + X[(7, 19)]
# mean[0] = mean[0] + X[(8, 0)]
# mean[1] = mean[1] + X[(8, 1)]
# mean[2] = mean[2] + X[(8, 2)]
# mean[3] = mean[3] + X[(8, 3)]
# mean[4] = mean[4] + X[(8, 4)]
# mean[5] = mean[5] + X[(8, 5)]
# mean[6] = mean[6] + X[(8, 6)]
# mean[7] = mean[7] + X[(8, 7)]
# mean[8] = mean[8] + X[(8, 8)]
# mean[9] = mean[9] + X[(8, 9)]
# mean[10] = mean[10] + X[(8, 10)]
# mean[11] = mean[11] + X[(8, 11)]
# mean[12] = mean[12] + X[(8, 12)]
# mean[13] = mean[13] + X[(8, 13)]
# mean[14] = mean[14] + X[(8, 14)]
# mean[15] = mean[15] + X[(8, 15)]
# mean[16] = mean[16] + X[(8, 16)]
# mean[17] = mean[17] + X[(8, 17)]
# mean[18] = mean[18] + X[(8, 18)]
# mean[19] = mean[19] + X[(8, 19)]
# mean[0] = mean[0] + X[(9, 0)]
# mean[1] = mean[1] + X[(9, 1)]
# mean[2] = mean[2] + X[(9, 2)]
# mean[3] = mean[3] + X[(9, 3)]
# mean[4] = mean[4] + X[(9, 4)]
# mean[5] = mean[5] + X[(9, 5)]
# mean[6] = mean[6] + X[(9, 6)]
# mean[7] = mean[7] + X[(9, 7)]
# mean[8] = mean[8] + X[(9, 8)]
# mean[9] = mean[9] + X[(9, 9)]
# mean[10] = mean[10] + X[(9, 10)]
# mean[11] = mean[11] + X[(9, 11)]
# mean[12] = mean[12] + X[(9, 12)]
# mean[13] = mean[13] + X[(9, 13)]
# mean[14] = mean[14] + X[(9, 14)]
# mean[15] = mean[15] + X[(9, 15)]
# mean[16] = mean[16] + X[(9, 16)]
# mean[17] = mean[17] + X[(9, 17)]
# mean[18] = mean[18] + X[(9, 18)]
# mean[19] = mean[19] + X[(9, 19)]
# mean[0] = mean[0] + X[(10, 0)]
# mean[1] = mean[1] + X[(10, 1)]
# mean[2] = mean[2] + X[(10, 2)]
# mean[3] = mean[3] + X[(10, 3)]
# mean[4] = mean[4] + X[(10, 4)]
# mean[5] = mean[5] + X[(10, 5)]
# mean[6] = mean[6] + X[(10, 6)]
# mean[7] = mean[7] + X[(10, 7)]
# mean[8] = mean[8] + X[(10, 8)]
# mean[9] = mean[9] + X[(10, 9)]
# mean[10] = mean[10] + X[(10, 10)]
# mean[11] = mean[11] + X[(10, 11)]
# mean[12] = mean[12] + X[(10, 12)]
# mean[13] = mean[13] + X[(10, 13)]
# mean[14] = mean[14] + X[(10, 14)]
# mean[15] = mean[15] + X[(10, 15)]
# mean[16] = mean[16] + X[(10, 16)]
# mean[17] = mean[17] + X[(10, 17)]
# mean[18] = mean[18] + X[(10, 18)]
# mean[19] = mean[19] + X[(10, 19)]
# mean[0] = mean[0] + X[(11, 0)]
# mean[1] = mean[1] + X[(11, 1)]
# mean[2] = mean[2] + X[(11, 2)]
# mean[3] = mean[3] + X[(11, 3)]
# mean[4] = mean[4] + X[(11, 4)]
# mean[5] = mean[5] + X[(11, 5)]
# mean[6] = mean[6] + X[(11, 6)]
# mean[7] = mean[7] + X[(11, 7)]
# mean[8] = mean[8] + X[(11, 8)]
# mean[9] = mean[9] + X[(11, 9)]
# mean[10] = mean[10] + X[(11, 10)]
# mean[11] = mean[11] + X[(11, 11)]
# mean[12] = mean[12] + X[(11, 12)]
# mean[13] = mean[13] + X[(11, 13)]
# mean[14] = mean[14] + X[(11, 14)]
# mean[15] = mean[15] + X[(11, 15)]
# mean[16] = mean[16] + X[(11, 16)]
# mean[17] = mean[17] + X[(11, 17)]
# mean[18] = mean[18] + X[(11, 18)]
# mean[19] = mean[19] + X[(11, 19)]
# mean[0] = mean[0] + X[(12, 0)]
# mean[1] = mean[1] + X[(12, 1)]
# mean[2] = mean[2] + X[(12, 2)]
# mean[3] = mean[3] + X[(12, 3)]
# mean[4] = mean[4] + X[(12, 4)]
# mean[5] = mean[5] + X[(12, 5)]
# mean[6] = mean[6] + X[(12, 6)]
# mean[7] = mean[7] + X[(12, 7)]
# mean[8] = mean[8] + X[(12, 8)]
# mean[9] = mean[9] + X[(12, 9)]
# mean[10] = mean[10] + X[(12, 10)]
# mean[11] = mean[11] + X[(12, 11)]
# mean[12] = mean[12] + X[(12, 12)]
# mean[13] = mean[13] + X[(12, 13)]
# mean[14] = mean[14] + X[(12, 14)]
# mean[15] = mean[15] + X[(12, 15)]
# mean[16] = mean[16] + X[(12, 16)]
# mean[17] = mean[17] + X[(12, 17)]
# mean[18] = mean[18] + X[(12, 18)]
# mean[19] = mean[19] + X[(12, 19)]
# mean[0] = mean[0] + X[(13, 0)]
# mean[1] = mean[1] + X[(13, 1)]
# mean[2] = mean[2] + X[(13, 2)]
# mean[3] = mean[3] + X[(13, 3)]
# mean[4] = mean[4] + X[(13, 4)]
# mean[5] = mean[5] + X[(13, 5)]
# mean[6] = mean[6] + X[(13, 6)]
# mean[7] = mean[7] + X[(13, 7)]
# mean[8] = mean[8] + X[(13, 8)]
# mean[9] = mean[9] + X[(13, 9)]
# mean[10] = mean[10] + X[(13, 10)]
# mean[11] = mean[11] + X[(13, 11)]
# mean[12] = mean[12] + X[(13, 12)]
# mean[13] = mean[13] + X[(13, 13)]
# mean[14] = mean[14] + X[(13, 14)]
# mean[15] = mean[15] + X[(13, 15)]
# mean[16] = mean[16] + X[(13, 16)]
# mean[17] = mean[17] + X[(13, 17)]
# mean[18] = mean[18] + X[(13, 18)]
# mean[19] = mean[19] + X[(13, 19)]
# mean[0] = mean[0] + X[(14, 0)]
# mean[1] = mean[1] + X[(14, 1)]
# mean[2] = mean[2] + X[(14, 2)]
# mean[3] = mean[3] + X[(14, 3)]
# mean[4] = mean[4] + X[(14, 4)]
# mean[5] = mean[5] + X[(14, 5)]
# mean[6] = mean[6] + X[(14, 6)]
# mean[7] = mean[7] + X[(14, 7)]
# mean[8] = mean[8] + X[(14, 8)]
# mean[9] = mean[9] + X[(14, 9)]
# mean[10] = mean[10] + X[(14, 10)]
# mean[11] = mean[11] + X[(14, 11)]
# mean[12] = mean[12] + X[(14, 12)]
# mean[13] = mean[13] + X[(14, 13)]
# mean[14] = mean[14] + X[(14, 14)]
# mean[15] = mean[15] + X[(14, 15)]
# mean[16] = mean[16] + X[(14, 16)]
# mean[17] = mean[17] + X[(14, 17)]
# mean[18] = mean[18] + X[(14, 18)]
# mean[19] = mean[19] + X[(14, 19)]
# mean[0] = mean[0] + X[(15, 0)]
# mean[1] = mean[1] + X[(15, 1)]
# mean[2] = mean[2] + X[(15, 2)]
# mean[3] = mean[3] + X[(15, 3)]
# mean[4] = mean[4] + X[(15, 4)]
# mean[5] = mean[5] + X[(15, 5)]
# mean[6] = mean[6] + X[(15, 6)]
# mean[7] = mean[7] + X[(15, 7)]
# mean[8] = mean[8] + X[(15, 8)]
# mean[9] = mean[9] + X[(15, 9)]
# mean[10] = mean[10] + X[(15, 10)]
# mean[11] = mean[11] + X[(15, 11)]
# mean[12] = mean[12] + X[(15, 12)]
# mean[13] = mean[13] + X[(15, 13)]
# mean[14] = mean[14] + X[(15, 14)]
# mean[15] = mean[15] + X[(15, 15)]
# mean[16] = mean[16] + X[(15, 16)]
# mean[17] = mean[17] + X[(15, 17)]
# mean[18] = mean[18] + X[(15, 18)]
# mean[19] = mean[19] + X[(15, 19)]
# mean[0] = mean[0] + X[(16, 0)]
# mean[1] = mean[1] + X[(16, 1)]
# mean[2] = mean[2] + X[(16, 2)]
# mean[3] = mean[3] + X[(16, 3)]
# mean[4] = mean[4] + X[(16, 4)]
# mean[5] = mean[5] + X[(16, 5)]
# mean[6] = mean[6] + X[(16, 6)]
# mean[7] = mean[7] + X[(16, 7)]
# mean[8] = mean[8] + X[(16, 8)]
# mean[9] = mean[9] + X[(16, 9)]
# mean[10] = mean[10] + X[(16, 10)]
# mean[11] = mean[11] + X[(16, 11)]
# mean[12] = mean[12] + X[(16, 12)]
# mean[13] = mean[13] + X[(16, 13)]
# mean[14] = mean[14] + X[(16, 14)]
# mean[15] = mean[15] + X[(16, 15)]
# mean[16] = mean[16] + X[(16, 16)]
# mean[17] = mean[17] + X[(16, 17)]
# mean[18] = mean[18] + X[(16, 18)]
# mean[19] = mean[19] + X[(16, 19)]
# mean[0] = mean[0] + X[(17, 0)]
# mean[1] = mean[1] + X[(17, 1)]
# mean[2] = mean[2] + X[(17, 2)]
# mean[3] = mean[3] + X[(17, 3)]
# mean[4] = mean[4] + X[(17, 4)]
# mean[5] = mean[5] + X[(17, 5)]
# mean[6] = mean[6] + X[(17, 6)]
# mean[7] = mean[7] + X[(17, 7)]
# mean[8] = mean[8] + X[(17, 8)]
# mean[9] = mean[9] + X[(17, 9)]
# mean[10] = mean[10] + X[(17, 10)]
# mean[11] = mean[11] + X[(17, 11)]
# mean[12] = mean[12] + X[(17, 12)]
# mean[13] = mean[13] + X[(17, 13)]
# mean[14] = mean[14] + X[(17, 14)]
# mean[15] = mean[15] + X[(17, 15)]
# mean[16] = mean[16] + X[(17, 16)]
# mean[17] = mean[17] + X[(17, 17)]
# mean[18] = mean[18] + X[(17, 18)]
# mean[19] = mean[19] + X[(17, 19)]
# mean[0] = mean[0] + X[(18, 0)]
# mean[1] = mean[1] + X[(18, 1)]
# mean[2] = mean[2] + X[(18, 2)]
# mean[3] = mean[3] + X[(18, 3)]
# mean[4] = mean[4] + X[(18, 4)]
# mean[5] = mean[5] + X[(18, 5)]
# mean[6] = mean[6] + X[(18, 6)]
# mean[7] = mean[7] + X[(18, 7)]
# mean[8] = mean[8] + X[(18, 8)]
# mean[9] = mean[9] + X[(18, 9)]
# mean[10] = mean[10] + X[(18, 10)]
# mean[11] = mean[11] + X[(18, 11)]
# mean[12] = mean[12] + X[(18, 12)]
# mean[13] = mean[13] + X[(18, 13)]
# mean[14] = mean[14] + X[(18, 14)]
# mean[15] = mean[15] + X[(18, 15)]
# mean[16] = mean[16] + X[(18, 16)]
# mean[17] = mean[17] + X[(18, 17)]
# mean[18] = mean[18] + X[(18, 18)]
# mean[19] = mean[19] + X[(18, 19)]
# mean[0] = mean[0] + X[(19, 0)]
# mean[1] = mean[1] + X[(19, 1)]
# mean[2] = mean[2] + X[(19, 2)]
# mean[3] = mean[3] + X[(19, 3)]
# mean[4] = mean[4] + X[(19, 4)]
# mean[5] = mean[5] + X[(19, 5)]
# mean[6] = mean[6] + X[(19, 6)]
# mean[7] = mean[7] + X[(19, 7)]
# mean[8] = mean[8] + X[(19, 8)]
# mean[9] = mean[9] + X[(19, 9)]
# mean[10] = mean[10] + X[(19, 10)]
# mean[11] = mean[11] + X[(19, 11)]
# mean[12] = mean[12] + X[(19, 12)]
# mean[13] = mean[13] + X[(19, 13)]
# mean[14] = mean[14] + X[(19, 14)]
# mean[15] = mean[15] + X[(19, 15)]
# mean[16] = mean[16] + X[(19, 16)]
# mean[17] = mean[17] + X[(19, 17)]
# mean[18] = mean[18] + X[(19, 18)]
# mean[19] = mean[19] + X[(19, 19)]
# mean[0] = mean[0] + X[(20, 0)]
# mean[1] = mean[1] + X[(20, 1)]
# mean[2] = mean[2] + X[(20, 2)]
# mean[3] = mean[3] + X[(20, 3)]
# mean[4] = mean[4] + X[(20, 4)]
# mean[5] = mean[5] + X[(20, 5)]
# mean[6] = mean[6] + X[(20, 6)]
# mean[7] = mean[7] + X[(20, 7)]
# mean[8] = mean[8] + X[(20, 8)]
# mean[9] = mean[9] + X[(20, 9)]
# mean[10] = mean[10] + X[(20, 10)]
# mean[11] = mean[11] + X[(20, 11)]
# mean[12] = mean[12] + X[(20, 12)]
# mean[13] = mean[13] + X[(20, 13)]
# mean[14] = mean[14] + X[(20, 14)]
# mean[15] = mean[15] + X[(20, 15)]
# mean[16] = mean[16] + X[(20, 16)]
# mean[17] = mean[17] + X[(20, 17)]
# mean[18] = mean[18] + X[(20, 18)]
# mean[19] = mean[19] + X[(20, 19)]
# mean[0] = mean[0] + X[(21, 0)]
# mean[1] = mean[1] + X[(21, 1)]
# mean[2] = mean[2] + X[(21, 2)]
# mean[3] = mean[3] + X[(21, 3)]
# mean[4] = mean[4] + X[(21, 4)]
# mean[5] = mean[5] + X[(21, 5)]
# mean[6] = mean[6] + X[(21, 6)]
# mean[7] = mean[7] + X[(21, 7)]
# mean[8] = mean[8] + X[(21, 8)]
# mean[9] = mean[9] + X[(21, 9)]
# mean[10] = mean[10] + X[(21, 10)]
# mean[11] = mean[11] + X[(21, 11)]
# mean[12] = mean[12] + X[(21, 12)]
# mean[13] = mean[13] + X[(21, 13)]
# mean[14] = mean[14] + X[(21, 14)]
# mean[15] = mean[15] + X[(21, 15)]
# mean[16] = mean[16] + X[(21, 16)]
# mean[17] = mean[17] + X[(21, 17)]
# mean[18] = mean[18] + X[(21, 18)]
# mean[19] = mean[19] + X[(21, 19)]
# mean[0] = mean[0] + X[(22, 0)]
# mean[1] = mean[1] + X[(22, 1)]
# mean[2] = mean[2] + X[(22, 2)]
# mean[3] = mean[3] + X[(22, 3)]
# mean[4] = mean[4] + X[(22, 4)]
# mean[5] = mean[5] + X[(22, 5)]
# mean[6] = mean[6] + X[(22, 6)]
# mean[7] = mean[7] + X[(22, 7)]
# mean[8] = mean[8] + X[(22, 8)]
# mean[9] = mean[9] + X[(22, 9)]
# mean[10] = mean[10] + X[(22, 10)]
# mean[11] = mean[11] + X[(22, 11)]
# mean[12] = mean[12] + X[(22, 12)]
# mean[13] = mean[13] + X[(22, 13)]
# mean[14] = mean[14] + X[(22, 14)]
# mean[15] = mean[15] + X[(22, 15)]
# mean[16] = mean[16] + X[(22, 16)]
# mean[17] = mean[17] + X[(22, 17)]
# mean[18] = mean[18] + X[(22, 18)]
# mean[19] = mean[19] + X[(22, 19)]
# mean[0] = mean[0] + X[(23, 0)]
# mean[1] = mean[1] + X[(23, 1)]
# mean[2] = mean[2] + X[(23, 2)]
# mean[3] = mean[3] + X[(23, 3)]
# mean[4] = mean[4] + X[(23, 4)]
# mean[5] = mean[5] + X[(23, 5)]
# mean[6] = mean[6] + X[(23, 6)]
# mean[7] = mean[7] + X[(23, 7)]
# mean[8] = mean[8] + X[(23, 8)]
# mean[9] = mean[9] + X[(23, 9)]
# mean[10] = mean[10] + X[(23, 10)]
# mean[11] = mean[11] + X[(23, 11)]
# mean[12] = mean[12] + X[(23, 12)]
# mean[13] = mean[13] + X[(23, 13)]
# mean[14] = mean[14] + X[(23, 14)]
# mean[15] = mean[15] + X[(23, 15)]
# mean[16] = mean[16] + X[(23, 16)]
# mean[17] = mean[17] + X[(23, 17)]
# mean[18] = mean[18] + X[(23, 18)]
# mean[19] = mean[19] + X[(23, 19)]
# mean[0] = mean[0] + X[(24, 0)]
# mean[1] = mean[1] + X[(24, 1)]
# mean[2] = mean[2] + X[(24, 2)]
# mean[3] = mean[3] + X[(24, 3)]
# mean[4] = mean[4] + X[(24, 4)]
# mean[5] = mean[5] + X[(24, 5)]
# mean[6] = mean[6] + X[(24, 6)]
# mean[7] = mean[7] + X[(24, 7)]
# mean[8] = mean[8] + X[(24, 8)]
# mean[9] = mean[9] + X[(24, 9)]
# mean[10] = mean[10] + X[(24, 10)]
# mean[11] = mean[11] + X[(24, 11)]
# mean[12] = mean[12] + X[(24, 12)]
# mean[13] = mean[13] + X[(24, 13)]
# mean[14] = mean[14] + X[(24, 14)]
# mean[15] = mean[15] + X[(24, 15)]
# mean[16] = mean[16] + X[(24, 16)]
# mean[17] = mean[17] + X[(24, 17)]
# mean[18] = mean[18] + X[(24, 18)]
# mean[19] = mean[19] + X[(24, 19)]
# mean[0] = mean[0] + X[(25, 0)]
# mean[1] = mean[1] + X[(25, 1)]
# mean[2] = mean[2] + X[(25, 2)]
# mean[3] = mean[3] + X[(25, 3)]
# mean[4] = mean[4] + X[(25, 4)]
# mean[5] = mean[5] + X[(25, 5)]
# mean[6] = mean[6] + X[(25, 6)]
# mean[7] = mean[7] + X[(25, 7)]
# mean[8] = mean[8] + X[(25, 8)]
# mean[9] = mean[9] + X[(25, 9)]
# mean[10] = mean[10] + X[(25, 10)]
# mean[11] = mean[11] + X[(25, 11)]
# mean[12] = mean[12] + X[(25, 12)]
# mean[13] = mean[13] + X[(25, 13)]
# mean[14] = mean[14] + X[(25, 14)]
# mean[15] = mean[15] + X[(25, 15)]
# mean[16] = mean[16] + X[(25, 16)]
# mean[17] = mean[17] + X[(25, 17)]
# mean[18] = mean[18] + X[(25, 18)]
# mean[19] = mean[19] + X[(25, 19)]
# mean[0] = mean[0] + X[(26, 0)]
# mean[1] = mean[1] + X[(26, 1)]
# mean[2] = mean[2] + X[(26, 2)]
# mean[3] = mean[3] + X[(26, 3)]
# mean[4] = mean[4] + X[(26, 4)]
# mean[5] = mean[5] + X[(26, 5)]
# mean[6] = mean[6] + X[(26, 6)]
# mean[7] = mean[7] + X[(26, 7)]
# mean[8] = mean[8] + X[(26, 8)]
# mean[9] = mean[9] + X[(26, 9)]
# mean[10] = mean[10] + X[(26, 10)]
# mean[11] = mean[11] + X[(26, 11)]
# mean[12] = mean[12] + X[(26, 12)]
# mean[13] = mean[13] + X[(26, 13)]
# mean[14] = mean[14] + X[(26, 14)]
# mean[15] = mean[15] + X[(26, 15)]
# mean[16] = mean[16] + X[(26, 16)]
# mean[17] = mean[17] + X[(26, 17)]
# mean[18] = mean[18] + X[(26, 18)]
# mean[19] = mean[19] + X[(26, 19)]
# mean[0] = mean[0] + X[(27, 0)]
# mean[1] = mean[1] + X[(27, 1)]
# mean[2] = mean[2] + X[(27, 2)]
# mean[3] = mean[3] + X[(27, 3)]
# mean[4] = mean[4] + X[(27, 4)]
# mean[5] = mean[5] + X[(27, 5)]
# mean[6] = mean[6] + X[(27, 6)]
# mean[7] = mean[7] + X[(27, 7)]
# mean[8] = mean[8] + X[(27, 8)]
# mean[9] = mean[9] + X[(27, 9)]
# mean[10] = mean[10] + X[(27, 10)]
# mean[11] = mean[11] + X[(27, 11)]
# mean[12] = mean[12] + X[(27, 12)]
# mean[13] = mean[13] + X[(27, 13)]
# mean[14] = mean[14] + X[(27, 14)]
# mean[15] = mean[15] + X[(27, 15)]
# mean[16] = mean[16] + X[(27, 16)]
# mean[17] = mean[17] + X[(27, 17)]
# mean[18] = mean[18] + X[(27, 18)]
# mean[19] = mean[19] + X[(27, 19)]
# mean[0] = mean[0] + X[(28, 0)]
# mean[1] = mean[1] + X[(28, 1)]
# mean[2] = mean[2] + X[(28, 2)]
# mean[3] = mean[3] + X[(28, 3)]
# mean[4] = mean[4] + X[(28, 4)]
# mean[5] = mean[5] + X[(28, 5)]
# mean[6] = mean[6] + X[(28, 6)]
# mean[7] = mean[7] + X[(28, 7)]
# mean[8] = mean[8] + X[(28, 8)]
# mean[9] = mean[9] + X[(28, 9)]
# mean[10] = mean[10] + X[(28, 10)]
# mean[11] = mean[11] + X[(28, 11)]
# mean[12] = mean[12] + X[(28, 12)]
# mean[13] = mean[13] + X[(28, 13)]
# mean[14] = mean[14] + X[(28, 14)]
# mean[15] = mean[15] + X[(28, 15)]
# mean[16] = mean[16] + X[(28, 16)]
# mean[17] = mean[17] + X[(28, 17)]
# mean[18] = mean[18] + X[(28, 18)]
# mean[19] = mean[19] + X[(28, 19)]
# mean[0] = mean[0] + X[(29, 0)]
# mean[1] = mean[1] + X[(29, 1)]
# mean[2] = mean[2] + X[(29, 2)]
# mean[3] = mean[3] + X[(29, 3)]
# mean[4] = mean[4] + X[(29, 4)]
# mean[5] = mean[5] + X[(29, 5)]
# mean[6] = mean[6] + X[(29, 6)]
# mean[7] = mean[7] + X[(29, 7)]
# mean[8] = mean[8] + X[(29, 8)]
# mean[9] = mean[9] + X[(29, 9)]
# mean[10] = mean[10] + X[(29, 10)]
# mean[11] = mean[11] + X[(29, 11)]
# mean[12] = mean[12] + X[(29, 12)]
# mean[13] = mean[13] + X[(29, 13)]
# mean[14] = mean[14] + X[(29, 14)]
# mean[15] = mean[15] + X[(29, 15)]
# mean[16] = mean[16] + X[(29, 16)]
# mean[17] = mean[17] + X[(29, 17)]
# mean[18] = mean[18] + X[(29, 18)]
# mean[19] = mean[19] + X[(29, 19)]
# mean[0] = mean[0] + X[(30, 0)]
# mean[1] = mean[1] + X[(30, 1)]
# mean[2] = mean[2] + X[(30, 2)]
# mean[3] = mean[3] + X[(30, 3)]
# mean[4] = mean[4] + X[(30, 4)]
# mean[5] = mean[5] + X[(30, 5)]
# mean[6] = mean[6] + X[(30, 6)]
# mean[7] = mean[7] + X[(30, 7)]
# mean[8] = mean[8] + X[(30, 8)]
# mean[9] = mean[9] + X[(30, 9)]
# mean[10] = mean[10] + X[(30, 10)]
# mean[11] = mean[11] + X[(30, 11)]
# mean[12] = mean[12] + X[(30, 12)]
# mean[13] = mean[13] + X[(30, 13)]
# mean[14] = mean[14] + X[(30, 14)]
# mean[15] = mean[15] + X[(30, 15)]
# mean[16] = mean[16] + X[(30, 16)]
# mean[17] = mean[17] + X[(30, 17)]
# mean[18] = mean[18] + X[(30, 18)]
# mean[19] = mean[19] + X[(30, 19)]
# mean[0] = mean[0] + X[(31, 0)]
# mean[1] = mean[1] + X[(31, 1)]
# mean[2] = mean[2] + X[(31, 2)]
# mean[3] = mean[3] + X[(31, 3)]
# mean[4] = mean[4] + X[(31, 4)]
# mean[5] = mean[5] + X[(31, 5)]
# mean[6] = mean[6] + X[(31, 6)]
# mean[7] = mean[7] + X[(31, 7)]
# mean[8] = mean[8] + X[(31, 8)]
# mean[9] = mean[9] + X[(31, 9)]
# mean[10] = mean[10] + X[(31, 10)]
# mean[11] = mean[11] + X[(31, 11)]
# mean[12] = mean[12] + X[(31, 12)]
# mean[13] = mean[13] + X[(31, 13)]
# mean[14] = mean[14] + X[(31, 14)]
# mean[15] = mean[15] + X[(31, 15)]
# mean[16] = mean[16] + X[(31, 16)]
# mean[17] = mean[17] + X[(31, 17)]
# mean[18] = mean[18] + X[(31, 18)]
# mean[19] = mean[19] + X[(31, 19)]
# mean[0] = mean[0] + X[(32, 0)]
# mean[1] = mean[1] + X[(32, 1)]
# mean[2] = mean[2] + X[(32, 2)]
# mean[3] = mean[3] + X[(32, 3)]
# mean[4] = mean[4] + X[(32, 4)]
# mean[5] = mean[5] + X[(32, 5)]
# mean[6] = mean[6] + X[(32, 6)]
# mean[7] = mean[7] + X[(32, 7)]
# mean[8] = mean[8] + X[(32, 8)]
# mean[9] = mean[9] + X[(32, 9)]
# mean[10] = mean[10] + X[(32, 10)]
# mean[11] = mean[11] + X[(32, 11)]
# mean[12] = mean[12] + X[(32, 12)]
# mean[13] = mean[13] + X[(32, 13)]
# mean[14] = mean[14] + X[(32, 14)]
# mean[15] = mean[15] + X[(32, 15)]
# mean[16] = mean[16] + X[(32, 16)]
# mean[17] = mean[17] + X[(32, 17)]
# mean[18] = mean[18] + X[(32, 18)]
# mean[19] = mean[19] + X[(32, 19)]
# mean[0] = mean[0] + X[(33, 0)]
# mean[1] = mean[1] + X[(33, 1)]
# mean[2] = mean[2] + X[(33, 2)]
# mean[3] = mean[3] + X[(33, 3)]
# mean[4] = mean[4] + X[(33, 4)]
# mean[5] = mean[5] + X[(33, 5)]
# mean[6] = mean[6] + X[(33, 6)]
# mean[7] = mean[7] + X[(33, 7)]
# mean[8] = mean[8] + X[(33, 8)]
# mean[9] = mean[9] + X[(33, 9)]
# mean[10] = mean[10] + X[(33, 10)]
# mean[11] = mean[11] + X[(33, 11)]
# mean[12] = mean[12] + X[(33, 12)]
# mean[13] = mean[13] + X[(33, 13)]
# mean[14] = mean[14] + X[(33, 14)]
# mean[15] = mean[15] + X[(33, 15)]
# mean[16] = mean[16] + X[(33, 16)]
# mean[17] = mean[17] + X[(33, 17)]
# mean[18] = mean[18] + X[(33, 18)]
# mean[19] = mean[19] + X[(33, 19)]
# mean[0] = mean[0] + X[(34, 0)]
# mean[1] = mean[1] + X[(34, 1)]
# mean[2] = mean[2] + X[(34, 2)]
# mean[3] = mean[3] + X[(34, 3)]
# mean[4] = mean[4] + X[(34, 4)]
# mean[5] = mean[5] + X[(34, 5)]
# mean[6] = mean[6] + X[(34, 6)]
# mean[7] = mean[7] + X[(34, 7)]
# mean[8] = mean[8] + X[(34, 8)]
# mean[9] = mean[9] + X[(34, 9)]
# mean[10] = mean[10] + X[(34, 10)]
# mean[11] = mean[11] + X[(34, 11)]
# mean[12] = mean[12] + X[(34, 12)]
# mean[13] = mean[13] + X[(34, 13)]
# mean[14] = mean[14] + X[(34, 14)]
# mean[15] = mean[15] + X[(34, 15)]
# mean[16] = mean[16] + X[(34, 16)]
# mean[17] = mean[17] + X[(34, 17)]
# mean[18] = mean[18] + X[(34, 18)]
# mean[19] = mean[19] + X[(34, 19)]
# mean[0] = mean[0] + X[(35, 0)]
# mean[1] = mean[1] + X[(35, 1)]
# mean[2] = mean[2] + X[(35, 2)]
# mean[3] = mean[3] + X[(35, 3)]
# mean[4] = mean[4] + X[(35, 4)]
# mean[5] = mean[5] + X[(35, 5)]
# mean[6] = mean[6] + X[(35, 6)]
# mean[7] = mean[7] + X[(35, 7)]
# mean[8] = mean[8] + X[(35, 8)]
# mean[9] = mean[9] + X[(35, 9)]
# mean[10] = mean[10] + X[(35, 10)]
# mean[11] = mean[11] + X[(35, 11)]
# mean[12] = mean[12] + X[(35, 12)]
# mean[13] = mean[13] + X[(35, 13)]
# mean[14] = mean[14] + X[(35, 14)]
# mean[15] = mean[15] + X[(35, 15)]
# mean[16] = mean[16] + X[(35, 16)]
# mean[17] = mean[17] + X[(35, 17)]
# mean[18] = mean[18] + X[(35, 18)]
# mean[19] = mean[19] + X[(35, 19)]
# mean[0] = mean[0] + X[(36, 0)]
# mean[1] = mean[1] + X[(36, 1)]
# mean[2] = mean[2] + X[(36, 2)]
# mean[3] = mean[3] + X[(36, 3)]
# mean[4] = mean[4] + X[(36, 4)]
# mean[5] = mean[5] + X[(36, 5)]
# mean[6] = mean[6] + X[(36, 6)]
# mean[7] = mean[7] + X[(36, 7)]
# mean[8] = mean[8] + X[(36, 8)]
# mean[9] = mean[9] + X[(36, 9)]
# mean[10] = mean[10] + X[(36, 10)]
# mean[11] = mean[11] + X[(36, 11)]
# mean[12] = mean[12] + X[(36, 12)]
# mean[13] = mean[13] + X[(36, 13)]
# mean[14] = mean[14] + X[(36, 14)]
# mean[15] = mean[15] + X[(36, 15)]
# mean[16] = mean[16] + X[(36, 16)]
# mean[17] = mean[17] + X[(36, 17)]
# mean[18] = mean[18] + X[(36, 18)]
# mean[19] = mean[19] + X[(36, 19)]
# mean[0] = mean[0] + X[(37, 0)]
# mean[1] = mean[1] + X[(37, 1)]
# mean[2] = mean[2] + X[(37, 2)]
# mean[3] = mean[3] + X[(37, 3)]
# mean[4] = mean[4] + X[(37, 4)]
# mean[5] = mean[5] + X[(37, 5)]
# mean[6] = mean[6] + X[(37, 6)]
# mean[7] = mean[7] + X[(37, 7)]
# mean[8] = mean[8] + X[(37, 8)]
# mean[9] = mean[9] + X[(37, 9)]
# mean[10] = mean[10] + X[(37, 10)]
# mean[11] = mean[11] + X[(37, 11)]
# mean[12] = mean[12] + X[(37, 12)]
# mean[13] = mean[13] + X[(37, 13)]
# mean[14] = mean[14] + X[(37, 14)]
# mean[15] = mean[15] + X[(37, 15)]
# mean[16] = mean[16] + X[(37, 16)]
# mean[17] = mean[17] + X[(37, 17)]
# mean[18] = mean[18] + X[(37, 18)]
# mean[19] = mean[19] + X[(37, 19)]
# mean[0] = mean[0] + X[(38, 0)]
# mean[1] = mean[1] + X[(38, 1)]
# mean[2] = mean[2] + X[(38, 2)]
# mean[3] = mean[3] + X[(38, 3)]
# mean[4] = mean[4] + X[(38, 4)]
# mean[5] = mean[5] + X[(38, 5)]
# mean[6] = mean[6] + X[(38, 6)]
# mean[7] = mean[7] + X[(38, 7)]
# mean[8] = mean[8] + X[(38, 8)]
# mean[9] = mean[9] + X[(38, 9)]
# mean[10] = mean[10] + X[(38, 10)]
# mean[11] = mean[11] + X[(38, 11)]
# mean[12] = mean[12] + X[(38, 12)]
# mean[13] = mean[13] + X[(38, 13)]
# mean[14] = mean[14] + X[(38, 14)]
# mean[15] = mean[15] + X[(38, 15)]
# mean[16] = mean[16] + X[(38, 16)]
# mean[17] = mean[17] + X[(38, 17)]
# mean[18] = mean[18] + X[(38, 18)]
# mean[19] = mean[19] + X[(38, 19)]
# mean[0] = mean[0] + X[(39, 0)]
# mean[1] = mean[1] + X[(39, 1)]
# mean[2] = mean[2] + X[(39, 2)]
# mean[3] = mean[3] + X[(39, 3)]
# mean[4] = mean[4] + X[(39, 4)]
# mean[5] = mean[5] + X[(39, 5)]
# mean[6] = mean[6] + X[(39, 6)]
# mean[7] = mean[7] + X[(39, 7)]
# mean[8] = mean[8] + X[(39, 8)]
# mean[9] = mean[9] + X[(39, 9)]
# mean[10] = mean[10] + X[(39, 10)]
# mean[11] = mean[11] + X[(39, 11)]
# mean[12] = mean[12] + X[(39, 12)]
# mean[13] = mean[13] + X[(39, 13)]
# mean[14] = mean[14] + X[(39, 14)]
# mean[15] = mean[15] + X[(39, 15)]
# mean[16] = mean[16] + X[(39, 16)]
# mean[17] = mean[17] + X[(39, 17)]
# mean[18] = mean[18] + X[(39, 18)]
# mean[19] = mean[19] + X[(39, 19)]
# mean[0] = mean[0] + X[(40, 0)]
# mean[1] = mean[1] + X[(40, 1)]
# mean[2] = mean[2] + X[(40, 2)]
# mean[3] = mean[3] + X[(40, 3)]
# mean[4] = mean[4] + X[(40, 4)]
# mean[5] = mean[5] + X[(40, 5)]
# mean[6] = mean[6] + X[(40, 6)]
# mean[7] = mean[7] + X[(40, 7)]
# mean[8] = mean[8] + X[(40, 8)]
# mean[9] = mean[9] + X[(40, 9)]
# mean[10] = mean[10] + X[(40, 10)]
# mean[11] = mean[11] + X[(40, 11)]
# mean[12] = mean[12] + X[(40, 12)]
# mean[13] = mean[13] + X[(40, 13)]
# mean[14] = mean[14] + X[(40, 14)]
# mean[15] = mean[15] + X[(40, 15)]
# mean[16] = mean[16] + X[(40, 16)]
# mean[17] = mean[17] + X[(40, 17)]
# mean[18] = mean[18] + X[(40, 18)]
# mean[19] = mean[19] + X[(40, 19)]
# mean[0] = mean[0] + X[(41, 0)]
# mean[1] = mean[1] + X[(41, 1)]
# mean[2] = mean[2] + X[(41, 2)]
# mean[3] = mean[3] + X[(41, 3)]
# mean[4] = mean[4] + X[(41, 4)]
# mean[5] = mean[5] + X[(41, 5)]
# mean[6] = mean[6] + X[(41, 6)]
# mean[7] = mean[7] + X[(41, 7)]
# mean[8] = mean[8] + X[(41, 8)]
# mean[9] = mean[9] + X[(41, 9)]
# mean[10] = mean[10] + X[(41, 10)]
# mean[11] = mean[11] + X[(41, 11)]
# mean[12] = mean[12] + X[(41, 12)]
# mean[13] = mean[13] + X[(41, 13)]
# mean[14] = mean[14] + X[(41, 14)]
# mean[15] = mean[15] + X[(41, 15)]
# mean[16] = mean[16] + X[(41, 16)]
# mean[17] = mean[17] + X[(41, 17)]
# mean[18] = mean[18] + X[(41, 18)]
# mean[19] = mean[19] + X[(41, 19)]
# mean[0] = mean[0] + X[(42, 0)]
# mean[1] = mean[1] + X[(42, 1)]
# mean[2] = mean[2] + X[(42, 2)]
# mean[3] = mean[3] + X[(42, 3)]
# mean[4] = mean[4] + X[(42, 4)]
# mean[5] = mean[5] + X[(42, 5)]
# mean[6] = mean[6] + X[(42, 6)]
# mean[7] = mean[7] + X[(42, 7)]
# mean[8] = mean[8] + X[(42, 8)]
# mean[9] = mean[9] + X[(42, 9)]
# mean[10] = mean[10] + X[(42, 10)]
# mean[11] = mean[11] + X[(42, 11)]
# mean[12] = mean[12] + X[(42, 12)]
# mean[13] = mean[13] + X[(42, 13)]
# mean[14] = mean[14] + X[(42, 14)]
# mean[15] = mean[15] + X[(42, 15)]
# mean[16] = mean[16] + X[(42, 16)]
# mean[17] = mean[17] + X[(42, 17)]
# mean[18] = mean[18] + X[(42, 18)]
# mean[19] = mean[19] + X[(42, 19)]
# mean[0] = mean[0] + X[(43, 0)]
# mean[1] = mean[1] + X[(43, 1)]
# mean[2] = mean[2] + X[(43, 2)]
# mean[3] = mean[3] + X[(43, 3)]
# mean[4] = mean[4] + X[(43, 4)]
# mean[5] = mean[5] + X[(43, 5)]
# mean[6] = mean[6] + X[(43, 6)]
# mean[7] = mean[7] + X[(43, 7)]
# mean[8] = mean[8] + X[(43, 8)]
# mean[9] = mean[9] + X[(43, 9)]
# mean[10] = mean[10] + X[(43, 10)]
# mean[11] = mean[11] + X[(43, 11)]
# mean[12] = mean[12] + X[(43, 12)]
# mean[13] = mean[13] + X[(43, 13)]
# mean[14] = mean[14] + X[(43, 14)]
# mean[15] = mean[15] + X[(43, 15)]
# mean[16] = mean[16] + X[(43, 16)]
# mean[17] = mean[17] + X[(43, 17)]
# mean[18] = mean[18] + X[(43, 18)]
# mean[19] = mean[19] + X[(43, 19)]
# mean[0] = mean[0] + X[(44, 0)]
# mean[1] = mean[1] + X[(44, 1)]
# mean[2] = mean[2] + X[(44, 2)]
# mean[3] = mean[3] + X[(44, 3)]
# mean[4] = mean[4] + X[(44, 4)]
# mean[5] = mean[5] + X[(44, 5)]
# mean[6] = mean[6] + X[(44, 6)]
# mean[7] = mean[7] + X[(44, 7)]
# mean[8] = mean[8] + X[(44, 8)]
# mean[9] = mean[9] + X[(44, 9)]
# mean[10] = mean[10] + X[(44, 10)]
# mean[11] = mean[11] + X[(44, 11)]
# mean[12] = mean[12] + X[(44, 12)]
# mean[13] = mean[13] + X[(44, 13)]
# mean[14] = mean[14] + X[(44, 14)]
# mean[15] = mean[15] + X[(44, 15)]
# mean[16] = mean[16] + X[(44, 16)]
# mean[17] = mean[17] + X[(44, 17)]
# mean[18] = mean[18] + X[(44, 18)]
# mean[19] = mean[19] + X[(44, 19)]
# mean[0] = mean[0] + X[(45, 0)]
# mean[1] = mean[1] + X[(45, 1)]
# mean[2] = mean[2] + X[(45, 2)]
# mean[3] = mean[3] + X[(45, 3)]
# mean[4] = mean[4] + X[(45, 4)]
# mean[5] = mean[5] + X[(45, 5)]
# mean[6] = mean[6] + X[(45, 6)]
# mean[7] = mean[7] + X[(45, 7)]
# mean[8] = mean[8] + X[(45, 8)]
# mean[9] = mean[9] + X[(45, 9)]
# mean[10] = mean[10] + X[(45, 10)]
# mean[11] = mean[11] + X[(45, 11)]
# mean[12] = mean[12] + X[(45, 12)]
# mean[13] = mean[13] + X[(45, 13)]
# mean[14] = mean[14] + X[(45, 14)]
# mean[15] = mean[15] + X[(45, 15)]
# mean[16] = mean[16] + X[(45, 16)]
# mean[17] = mean[17] + X[(45, 17)]
# mean[18] = mean[18] + X[(45, 18)]
# mean[19] = mean[19] + X[(45, 19)]
# mean[0] = mean[0] + X[(46, 0)]
# mean[1] = mean[1] + X[(46, 1)]
# mean[2] = mean[2] + X[(46, 2)]
# mean[3] = mean[3] + X[(46, 3)]
# mean[4] = mean[4] + X[(46, 4)]
# mean[5] = mean[5] + X[(46, 5)]
# mean[6] = mean[6] + X[(46, 6)]
# mean[7] = mean[7] + X[(46, 7)]
# mean[8] = mean[8] + X[(46, 8)]
# mean[9] = mean[9] + X[(46, 9)]
# mean[10] = mean[10] + X[(46, 10)]
# mean[11] = mean[11] + X[(46, 11)]
# mean[12] = mean[12] + X[(46, 12)]
# mean[13] = mean[13] + X[(46, 13)]
# mean[14] = mean[14] + X[(46, 14)]
# mean[15] = mean[15] + X[(46, 15)]
# mean[16] = mean[16] + X[(46, 16)]
# mean[17] = mean[17] + X[(46, 17)]
# mean[18] = mean[18] + X[(46, 18)]
# mean[19] = mean[19] + X[(46, 19)]
# mean[0] = mean[0] + X[(47, 0)]
# mean[1] = mean[1] + X[(47, 1)]
# mean[2] = mean[2] + X[(47, 2)]
# mean[3] = mean[3] + X[(47, 3)]
# mean[4] = mean[4] + X[(47, 4)]
# mean[5] = mean[5] + X[(47, 5)]
# mean[6] = mean[6] + X[(47, 6)]
# mean[7] = mean[7] + X[(47, 7)]
# mean[8] = mean[8] + X[(47, 8)]
# mean[9] = mean[9] + X[(47, 9)]
# mean[10] = mean[10] + X[(47, 10)]
# mean[11] = mean[11] + X[(47, 11)]
# mean[12] = mean[12] + X[(47, 12)]
# mean[13] = mean[13] + X[(47, 13)]
# mean[14] = mean[14] + X[(47, 14)]
# mean[15] = mean[15] + X[(47, 15)]
# mean[16] = mean[16] + X[(47, 16)]
# mean[17] = mean[17] + X[(47, 17)]
# mean[18] = mean[18] + X[(47, 18)]
# mean[19] = mean[19] + X[(47, 19)]
# mean[0] = mean[0] + X[(48, 0)]
# mean[1] = mean[1] + X[(48, 1)]
# mean[2] = mean[2] + X[(48, 2)]
# mean[3] = mean[3] + X[(48, 3)]
# mean[4] = mean[4] + X[(48, 4)]
# mean[5] = mean[5] + X[(48, 5)]
# mean[6] = mean[6] + X[(48, 6)]
# mean[7] = mean[7] + X[(48, 7)]
# mean[8] = mean[8] + X[(48, 8)]
# mean[9] = mean[9] + X[(48, 9)]
# mean[10] = mean[10] + X[(48, 10)]
# mean[11] = mean[11] + X[(48, 11)]
# mean[12] = mean[12] + X[(48, 12)]
# mean[13] = mean[13] + X[(48, 13)]
# mean[14] = mean[14] + X[(48, 14)]
# mean[15] = mean[15] + X[(48, 15)]
# mean[16] = mean[16] + X[(48, 16)]
# mean[17] = mean[17] + X[(48, 17)]
# mean[18] = mean[18] + X[(48, 18)]
# mean[19] = mean[19] + X[(48, 19)]
# mean[0] = mean[0] + X[(49, 0)]
# mean[1] = mean[1] + X[(49, 1)]
# mean[2] = mean[2] + X[(49, 2)]
# mean[3] = mean[3] + X[(49, 3)]
# mean[4] = mean[4] + X[(49, 4)]
# mean[5] = mean[5] + X[(49, 5)]
# mean[6] = mean[6] + X[(49, 6)]
# mean[7] = mean[7] + X[(49, 7)]
# mean[8] = mean[8] + X[(49, 8)]
# mean[9] = mean[9] + X[(49, 9)]
# mean[10] = mean[10] + X[(49, 10)]
# mean[11] = mean[11] + X[(49, 11)]
# mean[12] = mean[12] + X[(49, 12)]
# mean[13] = mean[13] + X[(49, 13)]
# mean[14] = mean[14] + X[(49, 14)]
# mean[15] = mean[15] + X[(49, 15)]
# mean[16] = mean[16] + X[(49, 16)]
# mean[17] = mean[17] + X[(49, 17)]
# mean[18] = mean[18] + X[(49, 18)]
# mean[19] = mean[19] + X[(49, 19)]
# mean[0] = mean[0] + X[(50, 0)]
# mean[1] = mean[1] + X[(50, 1)]
# mean[2] = mean[2] + X[(50, 2)]
# mean[3] = mean[3] + X[(50, 3)]
# mean[4] = mean[4] + X[(50, 4)]
# mean[5] = mean[5] + X[(50, 5)]
# mean[6] = mean[6] + X[(50, 6)]
# mean[7] = mean[7] + X[(50, 7)]
# mean[8] = mean[8] + X[(50, 8)]
# mean[9] = mean[9] + X[(50, 9)]
# mean[10] = mean[10] + X[(50, 10)]
# mean[11] = mean[11] + X[(50, 11)]
# mean[12] = mean[12] + X[(50, 12)]
# mean[13] = mean[13] + X[(50, 13)]
# mean[14] = mean[14] + X[(50, 14)]
# mean[15] = mean[15] + X[(50, 15)]
# mean[16] = mean[16] + X[(50, 16)]
# mean[17] = mean[17] + X[(50, 17)]
# mean[18] = mean[18] + X[(50, 18)]
# mean[19] = mean[19] + X[(50, 19)]
# mean[0] = mean[0] + X[(51, 0)]
# mean[1] = mean[1] + X[(51, 1)]
# mean[2] = mean[2] + X[(51, 2)]
# mean[3] = mean[3] + X[(51, 3)]
# mean[4] = mean[4] + X[(51, 4)]
# mean[5] = mean[5] + X[(51, 5)]
# mean[6] = mean[6] + X[(51, 6)]
# mean[7] = mean[7] + X[(51, 7)]
# mean[8] = mean[8] + X[(51, 8)]
# mean[9] = mean[9] + X[(51, 9)]
# mean[10] = mean[10] + X[(51, 10)]
# mean[11] = mean[11] + X[(51, 11)]
# mean[12] = mean[12] + X[(51, 12)]
# mean[13] = mean[13] + X[(51, 13)]
# mean[14] = mean[14] + X[(51, 14)]
# mean[15] = mean[15] + X[(51, 15)]
# mean[16] = mean[16] + X[(51, 16)]
# mean[17] = mean[17] + X[(51, 17)]
# mean[18] = mean[18] + X[(51, 18)]
# mean[19] = mean[19] + X[(51, 19)]
# mean[0] = mean[0] + X[(52, 0)]
# mean[1] = mean[1] + X[(52, 1)]
# mean[2] = mean[2] + X[(52, 2)]
# mean[3] = mean[3] + X[(52, 3)]
# mean[4] = mean[4] + X[(52, 4)]
# mean[5] = mean[5] + X[(52, 5)]
# mean[6] = mean[6] + X[(52, 6)]
# mean[7] = mean[7] + X[(52, 7)]
# mean[8] = mean[8] + X[(52, 8)]
# mean[9] = mean[9] + X[(52, 9)]
# mean[10] = mean[10] + X[(52, 10)]
# mean[11] = mean[11] + X[(52, 11)]
# mean[12] = mean[12] + X[(52, 12)]
# mean[13] = mean[13] + X[(52, 13)]
# mean[14] = mean[14] + X[(52, 14)]
# mean[15] = mean[15] + X[(52, 15)]
# mean[16] = mean[16] + X[(52, 16)]
# mean[17] = mean[17] + X[(52, 17)]
# mean[18] = mean[18] + X[(52, 18)]
# mean[19] = mean[19] + X[(52, 19)]
# mean[0] = mean[0] + X[(53, 0)]
# mean[1] = mean[1] + X[(53, 1)]
# mean[2] = mean[2] + X[(53, 2)]
# mean[3] = mean[3] + X[(53, 3)]
# mean[4] = mean[4] + X[(53, 4)]
# mean[5] = mean[5] + X[(53, 5)]
# mean[6] = mean[6] + X[(53, 6)]
# mean[7] = mean[7] + X[(53, 7)]
# mean[8] = mean[8] + X[(53, 8)]
# mean[9] = mean[9] + X[(53, 9)]
# mean[10] = mean[10] + X[(53, 10)]
# mean[11] = mean[11] + X[(53, 11)]
# mean[12] = mean[12] + X[(53, 12)]
# mean[13] = mean[13] + X[(53, 13)]
# mean[14] = mean[14] + X[(53, 14)]
# mean[15] = mean[15] + X[(53, 15)]
# mean[16] = mean[16] + X[(53, 16)]
# mean[17] = mean[17] + X[(53, 17)]
# mean[18] = mean[18] + X[(53, 18)]
# mean[19] = mean[19] + X[(53, 19)]
# mean[0] = mean[0] + X[(54, 0)]
# mean[1] = mean[1] + X[(54, 1)]
# mean[2] = mean[2] + X[(54, 2)]
# mean[3] = mean[3] + X[(54, 3)]
# mean[4] = mean[4] + X[(54, 4)]
# mean[5] = mean[5] + X[(54, 5)]
# mean[6] = mean[6] + X[(54, 6)]
# mean[7] = mean[7] + X[(54, 7)]
# mean[8] = mean[8] + X[(54, 8)]
# mean[9] = mean[9] + X[(54, 9)]
# mean[10] = mean[10] + X[(54, 10)]
# mean[11] = mean[11] + X[(54, 11)]
# mean[12] = mean[12] + X[(54, 12)]
# mean[13] = mean[13] + X[(54, 13)]
# mean[14] = mean[14] + X[(54, 14)]
# mean[15] = mean[15] + X[(54, 15)]
# mean[16] = mean[16] + X[(54, 16)]
# mean[17] = mean[17] + X[(54, 17)]
# mean[18] = mean[18] + X[(54, 18)]
# mean[19] = mean[19] + X[(54, 19)]
# mean[0] = mean[0] + X[(55, 0)]
# mean[1] = mean[1] + X[(55, 1)]
# mean[2] = mean[2] + X[(55, 2)]
# mean[3] = mean[3] + X[(55, 3)]
# mean[4] = mean[4] + X[(55, 4)]
# mean[5] = mean[5] + X[(55, 5)]
# mean[6] = mean[6] + X[(55, 6)]
# mean[7] = mean[7] + X[(55, 7)]
# mean[8] = mean[8] + X[(55, 8)]
# mean[9] = mean[9] + X[(55, 9)]
# mean[10] = mean[10] + X[(55, 10)]
# mean[11] = mean[11] + X[(55, 11)]
# mean[12] = mean[12] + X[(55, 12)]
# mean[13] = mean[13] + X[(55, 13)]
# mean[14] = mean[14] + X[(55, 14)]
# mean[15] = mean[15] + X[(55, 15)]
# mean[16] = mean[16] + X[(55, 16)]
# mean[17] = mean[17] + X[(55, 17)]
# mean[18] = mean[18] + X[(55, 18)]
# mean[19] = mean[19] + X[(55, 19)]
# mean[0] = mean[0] + X[(56, 0)]
# mean[1] = mean[1] + X[(56, 1)]
# mean[2] = mean[2] + X[(56, 2)]
# mean[3] = mean[3] + X[(56, 3)]
# mean[4] = mean[4] + X[(56, 4)]
# mean[5] = mean[5] + X[(56, 5)]
# mean[6] = mean[6] + X[(56, 6)]
# mean[7] = mean[7] + X[(56, 7)]
# mean[8] = mean[8] + X[(56, 8)]
# mean[9] = mean[9] + X[(56, 9)]
# mean[10] = mean[10] + X[(56, 10)]
# mean[11] = mean[11] + X[(56, 11)]
# mean[12] = mean[12] + X[(56, 12)]
# mean[13] = mean[13] + X[(56, 13)]
# mean[14] = mean[14] + X[(56, 14)]
# mean[15] = mean[15] + X[(56, 15)]
# mean[16] = mean[16] + X[(56, 16)]
# mean[17] = mean[17] + X[(56, 17)]
# mean[18] = mean[18] + X[(56, 18)]
# mean[19] = mean[19] + X[(56, 19)]
# mean[0] = mean[0] + X[(57, 0)]
# mean[1] = mean[1] + X[(57, 1)]
# mean[2] = mean[2] + X[(57, 2)]
# mean[3] = mean[3] + X[(57, 3)]
# mean[4] = mean[4] + X[(57, 4)]
# mean[5] = mean[5] + X[(57, 5)]
# mean[6] = mean[6] + X[(57, 6)]
# mean[7] = mean[7] + X[(57, 7)]
# mean[8] = mean[8] + X[(57, 8)]
# mean[9] = mean[9] + X[(57, 9)]
# mean[10] = mean[10] + X[(57, 10)]
# mean[11] = mean[11] + X[(57, 11)]
# mean[12] = mean[12] + X[(57, 12)]
# mean[13] = mean[13] + X[(57, 13)]
# mean[14] = mean[14] + X[(57, 14)]
# mean[15] = mean[15] + X[(57, 15)]
# mean[16] = mean[16] + X[(57, 16)]
# mean[17] = mean[17] + X[(57, 17)]
# mean[18] = mean[18] + X[(57, 18)]
# mean[19] = mean[19] + X[(57, 19)]
# mean[0] = mean[0] + X[(58, 0)]
# mean[1] = mean[1] + X[(58, 1)]
# mean[2] = mean[2] + X[(58, 2)]
# mean[3] = mean[3] + X[(58, 3)]
# mean[4] = mean[4] + X[(58, 4)]
# mean[5] = mean[5] + X[(58, 5)]
# mean[6] = mean[6] + X[(58, 6)]
# mean[7] = mean[7] + X[(58, 7)]
# mean[8] = mean[8] + X[(58, 8)]
# mean[9] = mean[9] + X[(58, 9)]
# mean[10] = mean[10] + X[(58, 10)]
# mean[11] = mean[11] + X[(58, 11)]
# mean[12] = mean[12] + X[(58, 12)]
# mean[13] = mean[13] + X[(58, 13)]
# mean[14] = mean[14] + X[(58, 14)]
# mean[15] = mean[15] + X[(58, 15)]
# mean[16] = mean[16] + X[(58, 16)]
# mean[17] = mean[17] + X[(58, 17)]
# mean[18] = mean[18] + X[(58, 18)]
# mean[19] = mean[19] + X[(58, 19)]
# mean[0] = mean[0] + X[(59, 0)]
# mean[1] = mean[1] + X[(59, 1)]
# mean[2] = mean[2] + X[(59, 2)]
# mean[3] = mean[3] + X[(59, 3)]
# mean[4] = mean[4] + X[(59, 4)]
# mean[5] = mean[5] + X[(59, 5)]
# mean[6] = mean[6] + X[(59, 6)]
# mean[7] = mean[7] + X[(59, 7)]
# mean[8] = mean[8] + X[(59, 8)]
# mean[9] = mean[9] + X[(59, 9)]
# mean[10] = mean[10] + X[(59, 10)]
# mean[11] = mean[11] + X[(59, 11)]
# mean[12] = mean[12] + X[(59, 12)]
# mean[13] = mean[13] + X[(59, 13)]
# mean[14] = mean[14] + X[(59, 14)]
# mean[15] = mean[15] + X[(59, 15)]
# mean[16] = mean[16] + X[(59, 16)]
# mean[17] = mean[17] + X[(59, 17)]
# mean[18] = mean[18] + X[(59, 18)]
# mean[19] = mean[19] + X[(59, 19)]
# mean[0] = mean[0] + X[(60, 0)]
# mean[1] = mean[1] + X[(60, 1)]
# mean[2] = mean[2] + X[(60, 2)]
# mean[3] = mean[3] + X[(60, 3)]
# mean[4] = mean[4] + X[(60, 4)]
# mean[5] = mean[5] + X[(60, 5)]
# mean[6] = mean[6] + X[(60, 6)]
# mean[7] = mean[7] + X[(60, 7)]
# mean[8] = mean[8] + X[(60, 8)]
# mean[9] = mean[9] + X[(60, 9)]
# mean[10] = mean[10] + X[(60, 10)]
# mean[11] = mean[11] + X[(60, 11)]
# mean[12] = mean[12] + X[(60, 12)]
# mean[13] = mean[13] + X[(60, 13)]
# mean[14] = mean[14] + X[(60, 14)]
# mean[15] = mean[15] + X[(60, 15)]
# mean[16] = mean[16] + X[(60, 16)]
# mean[17] = mean[17] + X[(60, 17)]
# mean[18] = mean[18] + X[(60, 18)]
# mean[19] = mean[19] + X[(60, 19)]
# mean[0] = mean[0] + X[(61, 0)]
# mean[1] = mean[1] + X[(61, 1)]
# mean[2] = mean[2] + X[(61, 2)]
# mean[3] = mean[3] + X[(61, 3)]
# mean[4] = mean[4] + X[(61, 4)]
# mean[5] = mean[5] + X[(61, 5)]
# mean[6] = mean[6] + X[(61, 6)]
# mean[7] = mean[7] + X[(61, 7)]
# mean[8] = mean[8] + X[(61, 8)]
# mean[9] = mean[9] + X[(61, 9)]
# mean[10] = mean[10] + X[(61, 10)]
# mean[11] = mean[11] + X[(61, 11)]
# mean[12] = mean[12] + X[(61, 12)]
# mean[13] = mean[13] + X[(61, 13)]
# mean[14] = mean[14] + X[(61, 14)]
# mean[15] = mean[15] + X[(61, 15)]
# mean[16] = mean[16] + X[(61, 16)]
# mean[17] = mean[17] + X[(61, 17)]
# mean[18] = mean[18] + X[(61, 18)]
# mean[19] = mean[19] + X[(61, 19)]
# mean[0] = mean[0] + X[(62, 0)]
# mean[1] = mean[1] + X[(62, 1)]
# mean[2] = mean[2] + X[(62, 2)]
# mean[3] = mean[3] + X[(62, 3)]
# mean[4] = mean[4] + X[(62, 4)]
# mean[5] = mean[5] + X[(62, 5)]
# mean[6] = mean[6] + X[(62, 6)]
# mean[7] = mean[7] + X[(62, 7)]
# mean[8] = mean[8] + X[(62, 8)]
# mean[9] = mean[9] + X[(62, 9)]
# mean[10] = mean[10] + X[(62, 10)]
# mean[11] = mean[11] + X[(62, 11)]
# mean[12] = mean[12] + X[(62, 12)]
# mean[13] = mean[13] + X[(62, 13)]
# mean[14] = mean[14] + X[(62, 14)]
# mean[15] = mean[15] + X[(62, 15)]
# mean[16] = mean[16] + X[(62, 16)]
# mean[17] = mean[17] + X[(62, 17)]
# mean[18] = mean[18] + X[(62, 18)]
# mean[19] = mean[19] + X[(62, 19)]
# mean[0] = mean[0] + X[(63, 0)]
# mean[1] = mean[1] + X[(63, 1)]
# mean[2] = mean[2] + X[(63, 2)]
# mean[3] = mean[3] + X[(63, 3)]
# mean[4] = mean[4] + X[(63, 4)]
# mean[5] = mean[5] + X[(63, 5)]
# mean[6] = mean[6] + X[(63, 6)]
# mean[7] = mean[7] + X[(63, 7)]
# mean[8] = mean[8] + X[(63, 8)]
# mean[9] = mean[9] + X[(63, 9)]
# mean[10] = mean[10] + X[(63, 10)]
# mean[11] = mean[11] + X[(63, 11)]
# mean[12] = mean[12] + X[(63, 12)]
# mean[13] = mean[13] + X[(63, 13)]
# mean[14] = mean[14] + X[(63, 14)]
# mean[15] = mean[15] + X[(63, 15)]
# mean[16] = mean[16] + X[(63, 16)]
# mean[17] = mean[17] + X[(63, 17)]
# mean[18] = mean[18] + X[(63, 18)]
# mean[19] = mean[19] + X[(63, 19)]
# mean[0] = mean[0] + X[(64, 0)]
# mean[1] = mean[1] + X[(64, 1)]
# mean[2] = mean[2] + X[(64, 2)]
# mean[3] = mean[3] + X[(64, 3)]
# mean[4] = mean[4] + X[(64, 4)]
# mean[5] = mean[5] + X[(64, 5)]
# mean[6] = mean[6] + X[(64, 6)]
# mean[7] = mean[7] + X[(64, 7)]
# mean[8] = mean[8] + X[(64, 8)]
# mean[9] = mean[9] + X[(64, 9)]
# mean[10] = mean[10] + X[(64, 10)]
# mean[11] = mean[11] + X[(64, 11)]
# mean[12] = mean[12] + X[(64, 12)]
# mean[13] = mean[13] + X[(64, 13)]
# mean[14] = mean[14] + X[(64, 14)]
# mean[15] = mean[15] + X[(64, 15)]
# mean[16] = mean[16] + X[(64, 16)]
# mean[17] = mean[17] + X[(64, 17)]
# mean[18] = mean[18] + X[(64, 18)]
# mean[19] = mean[19] + X[(64, 19)]
# mean[0] = mean[0] + X[(65, 0)]
# mean[1] = mean[1] + X[(65, 1)]
# mean[2] = mean[2] + X[(65, 2)]
# mean[3] = mean[3] + X[(65, 3)]
# mean[4] = mean[4] + X[(65, 4)]
# mean[5] = mean[5] + X[(65, 5)]
# mean[6] = mean[6] + X[(65, 6)]
# mean[7] = mean[7] + X[(65, 7)]
# mean[8] = mean[8] + X[(65, 8)]
# mean[9] = mean[9] + X[(65, 9)]
# mean[10] = mean[10] + X[(65, 10)]
# mean[11] = mean[11] + X[(65, 11)]
# mean[12] = mean[12] + X[(65, 12)]
# mean[13] = mean[13] + X[(65, 13)]
# mean[14] = mean[14] + X[(65, 14)]
# mean[15] = mean[15] + X[(65, 15)]
# mean[16] = mean[16] + X[(65, 16)]
# mean[17] = mean[17] + X[(65, 17)]
# mean[18] = mean[18] + X[(65, 18)]
# mean[19] = mean[19] + X[(65, 19)]
# mean[0] = mean[0] + X[(66, 0)]
# mean[1] = mean[1] + X[(66, 1)]
# mean[2] = mean[2] + X[(66, 2)]
# mean[3] = mean[3] + X[(66, 3)]
# mean[4] = mean[4] + X[(66, 4)]
# mean[5] = mean[5] + X[(66, 5)]
# mean[6] = mean[6] + X[(66, 6)]
# mean[7] = mean[7] + X[(66, 7)]
# mean[8] = mean[8] + X[(66, 8)]
# mean[9] = mean[9] + X[(66, 9)]
# mean[10] = mean[10] + X[(66, 10)]
# mean[11] = mean[11] + X[(66, 11)]
# mean[12] = mean[12] + X[(66, 12)]
# mean[13] = mean[13] + X[(66, 13)]
# mean[14] = mean[14] + X[(66, 14)]
# mean[15] = mean[15] + X[(66, 15)]
# mean[16] = mean[16] + X[(66, 16)]
# mean[17] = mean[17] + X[(66, 17)]
# mean[18] = mean[18] + X[(66, 18)]
# mean[19] = mean[19] + X[(66, 19)]
# mean[0] = mean[0] + X[(67, 0)]
# mean[1] = mean[1] + X[(67, 1)]
# mean[2] = mean[2] + X[(67, 2)]
# mean[3] = mean[3] + X[(67, 3)]
# mean[4] = mean[4] + X[(67, 4)]
# mean[5] = mean[5] + X[(67, 5)]
# mean[6] = mean[6] + X[(67, 6)]
# mean[7] = mean[7] + X[(67, 7)]
# mean[8] = mean[8] + X[(67, 8)]
# mean[9] = mean[9] + X[(67, 9)]
# mean[10] = mean[10] + X[(67, 10)]
# mean[11] = mean[11] + X[(67, 11)]
# mean[12] = mean[12] + X[(67, 12)]
# mean[13] = mean[13] + X[(67, 13)]
# mean[14] = mean[14] + X[(67, 14)]
# mean[15] = mean[15] + X[(67, 15)]
# mean[16] = mean[16] + X[(67, 16)]
# mean[17] = mean[17] + X[(67, 17)]
# mean[18] = mean[18] + X[(67, 18)]
# mean[19] = mean[19] + X[(67, 19)]
# mean[0] = mean[0] + X[(68, 0)]
# mean[1] = mean[1] + X[(68, 1)]
# mean[2] = mean[2] + X[(68, 2)]
# mean[3] = mean[3] + X[(68, 3)]
# mean[4] = mean[4] + X[(68, 4)]
# mean[5] = mean[5] + X[(68, 5)]
# mean[6] = mean[6] + X[(68, 6)]
# mean[7] = mean[7] + X[(68, 7)]
# mean[8] = mean[8] + X[(68, 8)]
# mean[9] = mean[9] + X[(68, 9)]
# mean[10] = mean[10] + X[(68, 10)]
# mean[11] = mean[11] + X[(68, 11)]
# mean[12] = mean[12] + X[(68, 12)]
# mean[13] = mean[13] + X[(68, 13)]
# mean[14] = mean[14] + X[(68, 14)]
# mean[15] = mean[15] + X[(68, 15)]
# mean[16] = mean[16] + X[(68, 16)]
# mean[17] = mean[17] + X[(68, 17)]
# mean[18] = mean[18] + X[(68, 18)]
# mean[19] = mean[19] + X[(68, 19)]
# mean[0] = mean[0] + X[(69, 0)]
# mean[1] = mean[1] + X[(69, 1)]
# mean[2] = mean[2] + X[(69, 2)]
# mean[3] = mean[3] + X[(69, 3)]
# mean[4] = mean[4] + X[(69, 4)]
# mean[5] = mean[5] + X[(69, 5)]
# mean[6] = mean[6] + X[(69, 6)]
# mean[7] = mean[7] + X[(69, 7)]
# mean[8] = mean[8] + X[(69, 8)]
# mean[9] = mean[9] + X[(69, 9)]
# mean[10] = mean[10] + X[(69, 10)]
# mean[11] = mean[11] + X[(69, 11)]
# mean[12] = mean[12] + X[(69, 12)]
# mean[13] = mean[13] + X[(69, 13)]
# mean[14] = mean[14] + X[(69, 14)]
# mean[15] = mean[15] + X[(69, 15)]
# mean[16] = mean[16] + X[(69, 16)]
# mean[17] = mean[17] + X[(69, 17)]
# mean[18] = mean[18] + X[(69, 18)]
# mean[19] = mean[19] + X[(69, 19)]
# mean[0] = mean[0] + X[(70, 0)]
# mean[1] = mean[1] + X[(70, 1)]
# mean[2] = mean[2] + X[(70, 2)]
# mean[3] = mean[3] + X[(70, 3)]
# mean[4] = mean[4] + X[(70, 4)]
# mean[5] = mean[5] + X[(70, 5)]
# mean[6] = mean[6] + X[(70, 6)]
# mean[7] = mean[7] + X[(70, 7)]
# mean[8] = mean[8] + X[(70, 8)]
# mean[9] = mean[9] + X[(70, 9)]
# mean[10] = mean[10] + X[(70, 10)]
# mean[11] = mean[11] + X[(70, 11)]
# mean[12] = mean[12] + X[(70, 12)]
# mean[13] = mean[13] + X[(70, 13)]
# mean[14] = mean[14] + X[(70, 14)]
# mean[15] = mean[15] + X[(70, 15)]
# mean[16] = mean[16] + X[(70, 16)]
# mean[17] = mean[17] + X[(70, 17)]
# mean[18] = mean[18] + X[(70, 18)]
# mean[19] = mean[19] + X[(70, 19)]
# mean[0] = mean[0] + X[(71, 0)]
# mean[1] = mean[1] + X[(71, 1)]
# mean[2] = mean[2] + X[(71, 2)]
# mean[3] = mean[3] + X[(71, 3)]
# mean[4] = mean[4] + X[(71, 4)]
# mean[5] = mean[5] + X[(71, 5)]
# mean[6] = mean[6] + X[(71, 6)]
# mean[7] = mean[7] + X[(71, 7)]
# mean[8] = mean[8] + X[(71, 8)]
# mean[9] = mean[9] + X[(71, 9)]
# mean[10] = mean[10] + X[(71, 10)]
# mean[11] = mean[11] + X[(71, 11)]
# mean[12] = mean[12] + X[(71, 12)]
# mean[13] = mean[13] + X[(71, 13)]
# mean[14] = mean[14] + X[(71, 14)]
# mean[15] = mean[15] + X[(71, 15)]
# mean[16] = mean[16] + X[(71, 16)]
# mean[17] = mean[17] + X[(71, 17)]
# mean[18] = mean[18] + X[(71, 18)]
# mean[19] = mean[19] + X[(71, 19)]
# mean[0] = mean[0] + X[(72, 0)]
# mean[1] = mean[1] + X[(72, 1)]
# mean[2] = mean[2] + X[(72, 2)]
# mean[3] = mean[3] + X[(72, 3)]
# mean[4] = mean[4] + X[(72, 4)]
# mean[5] = mean[5] + X[(72, 5)]
# mean[6] = mean[6] + X[(72, 6)]
# mean[7] = mean[7] + X[(72, 7)]
# mean[8] = mean[8] + X[(72, 8)]
# mean[9] = mean[9] + X[(72, 9)]
# mean[10] = mean[10] + X[(72, 10)]
# mean[11] = mean[11] + X[(72, 11)]
# mean[12] = mean[12] + X[(72, 12)]
# mean[13] = mean[13] + X[(72, 13)]
# mean[14] = mean[14] + X[(72, 14)]
# mean[15] = mean[15] + X[(72, 15)]
# mean[16] = mean[16] + X[(72, 16)]
# mean[17] = mean[17] + X[(72, 17)]
# mean[18] = mean[18] + X[(72, 18)]
# mean[19] = mean[19] + X[(72, 19)]
# mean[0] = mean[0] + X[(73, 0)]
# mean[1] = mean[1] + X[(73, 1)]
# mean[2] = mean[2] + X[(73, 2)]
# mean[3] = mean[3] + X[(73, 3)]
# mean[4] = mean[4] + X[(73, 4)]
# mean[5] = mean[5] + X[(73, 5)]
# mean[6] = mean[6] + X[(73, 6)]
# mean[7] = mean[7] + X[(73, 7)]
# mean[8] = mean[8] + X[(73, 8)]
# mean[9] = mean[9] + X[(73, 9)]
# mean[10] = mean[10] + X[(73, 10)]
# mean[11] = mean[11] + X[(73, 11)]
# mean[12] = mean[12] + X[(73, 12)]
# mean[13] = mean[13] + X[(73, 13)]
# mean[14] = mean[14] + X[(73, 14)]
# mean[15] = mean[15] + X[(73, 15)]
# mean[16] = mean[16] + X[(73, 16)]
# mean[17] = mean[17] + X[(73, 17)]
# mean[18] = mean[18] + X[(73, 18)]
# mean[19] = mean[19] + X[(73, 19)]
# mean[0] = mean[0] + X[(74, 0)]
# mean[1] = mean[1] + X[(74, 1)]
# mean[2] = mean[2] + X[(74, 2)]
# ...
# mean[7] = mean[7] + X[(976, 7)]
# mean[8] = mean[8] + X[(976, 8)]
# mean[9] = mean[9] + X[(976, 9)]
# mean[10] = mean[10] + X[(976, 10)]
# mean[11] = mean[11] + X[(976, 11)]
# mean[12] = mean[12] + X[(976, 12)]
# mean[13] = mean[13] + X[(976, 13)]
# mean[14] = mean[14] + X[(976, 14)]
# mean[15] = mean[15] + X[(976, 15)]
# mean[16] = mean[16] + X[(976, 16)]
# mean[17] = mean[17] + X[(976, 17)]
# mean[18] = mean[18] + X[(976, 18)]
# mean[19] = mean[19] + X[(976, 19)]
# mean[0] = mean[0] + X[(977, 0)]
# mean[1] = mean[1] + X[(977, 1)]
# mean[2] = mean[2] + X[(977, 2)]
# mean[3] = mean[3] + X[(977, 3)]
# mean[4] = mean[4] + X[(977, 4)]
# mean[5] = mean[5] + X[(977, 5)]
# mean[6] = mean[6] + X[(977, 6)]
# mean[7] = mean[7] + X[(977, 7)]
# mean[8] = mean[8] + X[(977, 8)]
# mean[9] = mean[9] + X[(977, 9)]
# mean[10] = mean[10] + X[(977, 10)]
# mean[11] = mean[11] + X[(977, 11)]
# mean[12] = mean[12] + X[(977, 12)]
# mean[13] = mean[13] + X[(977, 13)]
# mean[14] = mean[14] + X[(977, 14)]
# mean[15] = mean[15] + X[(977, 15)]
# mean[16] = mean[16] + X[(977, 16)]
# mean[17] = mean[17] + X[(977, 17)]
# mean[18] = mean[18] + X[(977, 18)]
# mean[19] = mean[19] + X[(977, 19)]
# mean[0] = mean[0] + X[(978, 0)]
# mean[1] = mean[1] + X[(978, 1)]
# mean[2] = mean[2] + X[(978, 2)]
# mean[3] = mean[3] + X[(978, 3)]
# mean[4] = mean[4] + X[(978, 4)]
# mean[5] = mean[5] + X[(978, 5)]
# mean[6] = mean[6] + X[(978, 6)]
# mean[7] = mean[7] + X[(978, 7)]
# mean[8] = mean[8] + X[(978, 8)]
# mean[9] = mean[9] + X[(978, 9)]
# mean[10] = mean[10] + X[(978, 10)]
# mean[11] = mean[11] + X[(978, 11)]
# mean[12] = mean[12] + X[(978, 12)]
# mean[13] = mean[13] + X[(978, 13)]
# mean[14] = mean[14] + X[(978, 14)]
# mean[15] = mean[15] + X[(978, 15)]
# mean[16] = mean[16] + X[(978, 16)]
# mean[17] = mean[17] + X[(978, 17)]
# mean[18] = mean[18] + X[(978, 18)]
# mean[19] = mean[19] + X[(978, 19)]
# mean[0] = mean[0] + X[(979, 0)]
# mean[1] = mean[1] + X[(979, 1)]
# mean[2] = mean[2] + X[(979, 2)]
# mean[3] = mean[3] + X[(979, 3)]
# mean[4] = mean[4] + X[(979, 4)]
# mean[5] = mean[5] + X[(979, 5)]
# mean[6] = mean[6] + X[(979, 6)]
# mean[7] = mean[7] + X[(979, 7)]
# mean[8] = mean[8] + X[(979, 8)]
# mean[9] = mean[9] + X[(979, 9)]
# mean[10] = mean[10] + X[(979, 10)]
# mean[11] = mean[11] + X[(979, 11)]
# mean[12] = mean[12] + X[(979, 12)]
# mean[13] = mean[13] + X[(979, 13)]
# mean[14] = mean[14] + X[(979, 14)]
# mean[15] = mean[15] + X[(979, 15)]
# mean[16] = mean[16] + X[(979, 16)]
# mean[17] = mean[17] + X[(979, 17)]
# mean[18] = mean[18] + X[(979, 18)]
# mean[19] = mean[19] + X[(979, 19)]
# mean[0] = mean[0] + X[(980, 0)]
# mean[1] = mean[1] + X[(980, 1)]
# mean[2] = mean[2] + X[(980, 2)]
# mean[3] = mean[3] + X[(980, 3)]
# mean[4] = mean[4] + X[(980, 4)]
# mean[5] = mean[5] + X[(980, 5)]
# mean[6] = mean[6] + X[(980, 6)]
# mean[7] = mean[7] + X[(980, 7)]
# mean[8] = mean[8] + X[(980, 8)]
# mean[9] = mean[9] + X[(980, 9)]
# mean[10] = mean[10] + X[(980, 10)]
# mean[11] = mean[11] + X[(980, 11)]
# mean[12] = mean[12] + X[(980, 12)]
# mean[13] = mean[13] + X[(980, 13)]
# mean[14] = mean[14] + X[(980, 14)]
# mean[15] = mean[15] + X[(980, 15)]
# mean[16] = mean[16] + X[(980, 16)]
# mean[17] = mean[17] + X[(980, 17)]
# mean[18] = mean[18] + X[(980, 18)]
# mean[19] = mean[19] + X[(980, 19)]
# mean[0] = mean[0] + X[(981, 0)]
# mean[1] = mean[1] + X[(981, 1)]
# mean[2] = mean[2] + X[(981, 2)]
# mean[3] = mean[3] + X[(981, 3)]
# mean[4] = mean[4] + X[(981, 4)]
# mean[5] = mean[5] + X[(981, 5)]
# mean[6] = mean[6] + X[(981, 6)]
# mean[7] = mean[7] + X[(981, 7)]
# mean[8] = mean[8] + X[(981, 8)]
# mean[9] = mean[9] + X[(981, 9)]
# mean[10] = mean[10] + X[(981, 10)]
# mean[11] = mean[11] + X[(981, 11)]
# mean[12] = mean[12] + X[(981, 12)]
# mean[13] = mean[13] + X[(981, 13)]
# mean[14] = mean[14] + X[(981, 14)]
# mean[15] = mean[15] + X[(981, 15)]
# mean[16] = mean[16] + X[(981, 16)]
# mean[17] = mean[17] + X[(981, 17)]
# mean[18] = mean[18] + X[(981, 18)]
# mean[19] = mean[19] + X[(981, 19)]
# mean[0] = mean[0] + X[(982, 0)]
# mean[1] = mean[1] + X[(982, 1)]
# mean[2] = mean[2] + X[(982, 2)]
# mean[3] = mean[3] + X[(982, 3)]
# mean[4] = mean[4] + X[(982, 4)]
# mean[5] = mean[5] + X[(982, 5)]
# mean[6] = mean[6] + X[(982, 6)]
# mean[7] = mean[7] + X[(982, 7)]
# mean[8] = mean[8] + X[(982, 8)]
# mean[9] = mean[9] + X[(982, 9)]
# mean[10] = mean[10] + X[(982, 10)]
# mean[11] = mean[11] + X[(982, 11)]
# mean[12] = mean[12] + X[(982, 12)]
# mean[13] = mean[13] + X[(982, 13)]
# mean[14] = mean[14] + X[(982, 14)]
# mean[15] = mean[15] + X[(982, 15)]
# mean[16] = mean[16] + X[(982, 16)]
# mean[17] = mean[17] + X[(982, 17)]
# mean[18] = mean[18] + X[(982, 18)]
# mean[19] = mean[19] + X[(982, 19)]
# mean[0] = mean[0] + X[(983, 0)]
# mean[1] = mean[1] + X[(983, 1)]
# mean[2] = mean[2] + X[(983, 2)]
# mean[3] = mean[3] + X[(983, 3)]
# mean[4] = mean[4] + X[(983, 4)]
# mean[5] = mean[5] + X[(983, 5)]
# mean[6] = mean[6] + X[(983, 6)]
# mean[7] = mean[7] + X[(983, 7)]
# mean[8] = mean[8] + X[(983, 8)]
# mean[9] = mean[9] + X[(983, 9)]
# mean[10] = mean[10] + X[(983, 10)]
# mean[11] = mean[11] + X[(983, 11)]
# mean[12] = mean[12] + X[(983, 12)]
# mean[13] = mean[13] + X[(983, 13)]
# mean[14] = mean[14] + X[(983, 14)]
# mean[15] = mean[15] + X[(983, 15)]
# mean[16] = mean[16] + X[(983, 16)]
# mean[17] = mean[17] + X[(983, 17)]
# mean[18] = mean[18] + X[(983, 18)]
# mean[19] = mean[19] + X[(983, 19)]
# mean[0] = mean[0] + X[(984, 0)]
# mean[1] = mean[1] + X[(984, 1)]
# mean[2] = mean[2] + X[(984, 2)]
# mean[3] = mean[3] + X[(984, 3)]
# mean[4] = mean[4] + X[(984, 4)]
# mean[5] = mean[5] + X[(984, 5)]
# mean[6] = mean[6] + X[(984, 6)]
# mean[7] = mean[7] + X[(984, 7)]
# mean[8] = mean[8] + X[(984, 8)]
# mean[9] = mean[9] + X[(984, 9)]
# mean[10] = mean[10] + X[(984, 10)]
# mean[11] = mean[11] + X[(984, 11)]
# mean[12] = mean[12] + X[(984, 12)]
# mean[13] = mean[13] + X[(984, 13)]
# mean[14] = mean[14] + X[(984, 14)]
# mean[15] = mean[15] + X[(984, 15)]
# mean[16] = mean[16] + X[(984, 16)]
# mean[17] = mean[17] + X[(984, 17)]
# mean[18] = mean[18] + X[(984, 18)]
# mean[19] = mean[19] + X[(984, 19)]
# mean[0] = mean[0] + X[(985, 0)]
# mean[1] = mean[1] + X[(985, 1)]
# mean[2] = mean[2] + X[(985, 2)]
# mean[3] = mean[3] + X[(985, 3)]
# mean[4] = mean[4] + X[(985, 4)]
# mean[5] = mean[5] + X[(985, 5)]
# mean[6] = mean[6] + X[(985, 6)]
# mean[7] = mean[7] + X[(985, 7)]
# mean[8] = mean[8] + X[(985, 8)]
# mean[9] = mean[9] + X[(985, 9)]
# mean[10] = mean[10] + X[(985, 10)]
# mean[11] = mean[11] + X[(985, 11)]
# mean[12] = mean[12] + X[(985, 12)]
# mean[13] = mean[13] + X[(985, 13)]
# mean[14] = mean[14] + X[(985, 14)]
# mean[15] = mean[15] + X[(985, 15)]
# mean[16] = mean[16] + X[(985, 16)]
# mean[17] = mean[17] + X[(985, 17)]
# mean[18] = mean[18] + X[(985, 18)]
# mean[19] = mean[19] + X[(985, 19)]
# mean[0] = mean[0] + X[(986, 0)]
# mean[1] = mean[1] + X[(986, 1)]
# mean[2] = mean[2] + X[(986, 2)]
# mean[3] = mean[3] + X[(986, 3)]
# mean[4] = mean[4] + X[(986, 4)]
# mean[5] = mean[5] + X[(986, 5)]
# mean[6] = mean[6] + X[(986, 6)]
# mean[7] = mean[7] + X[(986, 7)]
# mean[8] = mean[8] + X[(986, 8)]
# mean[9] = mean[9] + X[(986, 9)]
# mean[10] = mean[10] + X[(986, 10)]
# mean[11] = mean[11] + X[(986, 11)]
# mean[12] = mean[12] + X[(986, 12)]
# mean[13] = mean[13] + X[(986, 13)]
# mean[14] = mean[14] + X[(986, 14)]
# mean[15] = mean[15] + X[(986, 15)]
# mean[16] = mean[16] + X[(986, 16)]
# mean[17] = mean[17] + X[(986, 17)]
# mean[18] = mean[18] + X[(986, 18)]
# mean[19] = mean[19] + X[(986, 19)]
# mean[0] = mean[0] + X[(987, 0)]
# mean[1] = mean[1] + X[(987, 1)]
# mean[2] = mean[2] + X[(987, 2)]
# mean[3] = mean[3] + X[(987, 3)]
# mean[4] = mean[4] + X[(987, 4)]
# mean[5] = mean[5] + X[(987, 5)]
# mean[6] = mean[6] + X[(987, 6)]
# mean[7] = mean[7] + X[(987, 7)]
# mean[8] = mean[8] + X[(987, 8)]
# mean[9] = mean[9] + X[(987, 9)]
# mean[10] = mean[10] + X[(987, 10)]
# mean[11] = mean[11] + X[(987, 11)]
# mean[12] = mean[12] + X[(987, 12)]
# mean[13] = mean[13] + X[(987, 13)]
# mean[14] = mean[14] + X[(987, 14)]
# mean[15] = mean[15] + X[(987, 15)]
# mean[16] = mean[16] + X[(987, 16)]
# mean[17] = mean[17] + X[(987, 17)]
# mean[18] = mean[18] + X[(987, 18)]
# mean[19] = mean[19] + X[(987, 19)]
# mean[0] = mean[0] + X[(988, 0)]
# mean[1] = mean[1] + X[(988, 1)]
# mean[2] = mean[2] + X[(988, 2)]
# mean[3] = mean[3] + X[(988, 3)]
# mean[4] = mean[4] + X[(988, 4)]
# mean[5] = mean[5] + X[(988, 5)]
# mean[6] = mean[6] + X[(988, 6)]
# mean[7] = mean[7] + X[(988, 7)]
# mean[8] = mean[8] + X[(988, 8)]
# mean[9] = mean[9] + X[(988, 9)]
# mean[10] = mean[10] + X[(988, 10)]
# mean[11] = mean[11] + X[(988, 11)]
# mean[12] = mean[12] + X[(988, 12)]
# mean[13] = mean[13] + X[(988, 13)]
# mean[14] = mean[14] + X[(988, 14)]
# mean[15] = mean[15] + X[(988, 15)]
# mean[16] = mean[16] + X[(988, 16)]
# mean[17] = mean[17] + X[(988, 17)]
# mean[18] = mean[18] + X[(988, 18)]
# mean[19] = mean[19] + X[(988, 19)]
# mean[0] = mean[0] + X[(989, 0)]
# mean[1] = mean[1] + X[(989, 1)]
# mean[2] = mean[2] + X[(989, 2)]
# mean[3] = mean[3] + X[(989, 3)]
# mean[4] = mean[4] + X[(989, 4)]
# mean[5] = mean[5] + X[(989, 5)]
# mean[6] = mean[6] + X[(989, 6)]
# mean[7] = mean[7] + X[(989, 7)]
# mean[8] = mean[8] + X[(989, 8)]
# mean[9] = mean[9] + X[(989, 9)]
# mean[10] = mean[10] + X[(989, 10)]
# mean[11] = mean[11] + X[(989, 11)]
# mean[12] = mean[12] + X[(989, 12)]
# mean[13] = mean[13] + X[(989, 13)]
# mean[14] = mean[14] + X[(989, 14)]
# mean[15] = mean[15] + X[(989, 15)]
# mean[16] = mean[16] + X[(989, 16)]
# mean[17] = mean[17] + X[(989, 17)]
# mean[18] = mean[18] + X[(989, 18)]
# mean[19] = mean[19] + X[(989, 19)]
# mean[0] = mean[0] + X[(990, 0)]
# mean[1] = mean[1] + X[(990, 1)]
# mean[2] = mean[2] + X[(990, 2)]
# mean[3] = mean[3] + X[(990, 3)]
# mean[4] = mean[4] + X[(990, 4)]
# mean[5] = mean[5] + X[(990, 5)]
# mean[6] = mean[6] + X[(990, 6)]
# mean[7] = mean[7] + X[(990, 7)]
# mean[8] = mean[8] + X[(990, 8)]
# mean[9] = mean[9] + X[(990, 9)]
# mean[10] = mean[10] + X[(990, 10)]
# mean[11] = mean[11] + X[(990, 11)]
# mean[12] = mean[12] + X[(990, 12)]
# mean[13] = mean[13] + X[(990, 13)]
# mean[14] = mean[14] + X[(990, 14)]
# mean[15] = mean[15] + X[(990, 15)]
# mean[16] = mean[16] + X[(990, 16)]
# mean[17] = mean[17] + X[(990, 17)]
# mean[18] = mean[18] + X[(990, 18)]
# mean[19] = mean[19] + X[(990, 19)]
# mean[0] = mean[0] + X[(991, 0)]
# mean[1] = mean[1] + X[(991, 1)]
# mean[2] = mean[2] + X[(991, 2)]
# mean[3] = mean[3] + X[(991, 3)]
# mean[4] = mean[4] + X[(991, 4)]
# mean[5] = mean[5] + X[(991, 5)]
# mean[6] = mean[6] + X[(991, 6)]
# mean[7] = mean[7] + X[(991, 7)]
# mean[8] = mean[8] + X[(991, 8)]
# mean[9] = mean[9] + X[(991, 9)]
# mean[10] = mean[10] + X[(991, 10)]
# mean[11] = mean[11] + X[(991, 11)]
# mean[12] = mean[12] + X[(991, 12)]
# mean[13] = mean[13] + X[(991, 13)]
# mean[14] = mean[14] + X[(991, 14)]
# mean[15] = mean[15] + X[(991, 15)]
# mean[16] = mean[16] + X[(991, 16)]
# mean[17] = mean[17] + X[(991, 17)]
# mean[18] = mean[18] + X[(991, 18)]
# mean[19] = mean[19] + X[(991, 19)]
# mean[0] = mean[0] + X[(992, 0)]
# mean[1] = mean[1] + X[(992, 1)]
# mean[2] = mean[2] + X[(992, 2)]
# mean[3] = mean[3] + X[(992, 3)]
# mean[4] = mean[4] + X[(992, 4)]
# mean[5] = mean[5] + X[(992, 5)]
# mean[6] = mean[6] + X[(992, 6)]
# mean[7] = mean[7] + X[(992, 7)]
# mean[8] = mean[8] + X[(992, 8)]
# mean[9] = mean[9] + X[(992, 9)]
# mean[10] = mean[10] + X[(992, 10)]
# mean[11] = mean[11] + X[(992, 11)]
# mean[12] = mean[12] + X[(992, 12)]
# mean[13] = mean[13] + X[(992, 13)]
# mean[14] = mean[14] + X[(992, 14)]
# mean[15] = mean[15] + X[(992, 15)]
# mean[16] = mean[16] + X[(992, 16)]
# mean[17] = mean[17] + X[(992, 17)]
# mean[18] = mean[18] + X[(992, 18)]
# mean[19] = mean[19] + X[(992, 19)]
# mean[0] = mean[0] + X[(993, 0)]
# mean[1] = mean[1] + X[(993, 1)]
# mean[2] = mean[2] + X[(993, 2)]
# mean[3] = mean[3] + X[(993, 3)]
# mean[4] = mean[4] + X[(993, 4)]
# mean[5] = mean[5] + X[(993, 5)]
# mean[6] = mean[6] + X[(993, 6)]
# mean[7] = mean[7] + X[(993, 7)]
# mean[8] = mean[8] + X[(993, 8)]
# mean[9] = mean[9] + X[(993, 9)]
# mean[10] = mean[10] + X[(993, 10)]
# mean[11] = mean[11] + X[(993, 11)]
# mean[12] = mean[12] + X[(993, 12)]
# mean[13] = mean[13] + X[(993, 13)]
# mean[14] = mean[14] + X[(993, 14)]
# mean[15] = mean[15] + X[(993, 15)]
# mean[16] = mean[16] + X[(993, 16)]
# mean[17] = mean[17] + X[(993, 17)]
# mean[18] = mean[18] + X[(993, 18)]
# mean[19] = mean[19] + X[(993, 19)]
# mean[0] = mean[0] + X[(994, 0)]
# mean[1] = mean[1] + X[(994, 1)]
# mean[2] = mean[2] + X[(994, 2)]
# mean[3] = mean[3] + X[(994, 3)]
# mean[4] = mean[4] + X[(994, 4)]
# mean[5] = mean[5] + X[(994, 5)]
# mean[6] = mean[6] + X[(994, 6)]
# mean[7] = mean[7] + X[(994, 7)]
# mean[8] = mean[8] + X[(994, 8)]
# mean[9] = mean[9] + X[(994, 9)]
# mean[10] = mean[10] + X[(994, 10)]
# mean[11] = mean[11] + X[(994, 11)]
# mean[12] = mean[12] + X[(994, 12)]
# mean[13] = mean[13] + X[(994, 13)]
# mean[14] = mean[14] + X[(994, 14)]
# mean[15] = mean[15] + X[(994, 15)]
# mean[16] = mean[16] + X[(994, 16)]
# mean[17] = mean[17] + X[(994, 17)]
# mean[18] = mean[18] + X[(994, 18)]
# mean[19] = mean[19] + X[(994, 19)]
# mean[0] = mean[0] + X[(995, 0)]
# mean[1] = mean[1] + X[(995, 1)]
# mean[2] = mean[2] + X[(995, 2)]
# mean[3] = mean[3] + X[(995, 3)]
# mean[4] = mean[4] + X[(995, 4)]
# mean[5] = mean[5] + X[(995, 5)]
# mean[6] = mean[6] + X[(995, 6)]
# mean[7] = mean[7] + X[(995, 7)]
# mean[8] = mean[8] + X[(995, 8)]
# mean[9] = mean[9] + X[(995, 9)]
# mean[10] = mean[10] + X[(995, 10)]
# mean[11] = mean[11] + X[(995, 11)]
# mean[12] = mean[12] + X[(995, 12)]
# mean[13] = mean[13] + X[(995, 13)]
# mean[14] = mean[14] + X[(995, 14)]
# mean[15] = mean[15] + X[(995, 15)]
# mean[16] = mean[16] + X[(995, 16)]
# mean[17] = mean[17] + X[(995, 17)]
# mean[18] = mean[18] + X[(995, 18)]
# mean[19] = mean[19] + X[(995, 19)]
# mean[0] = mean[0] + X[(996, 0)]
# mean[1] = mean[1] + X[(996, 1)]
# mean[2] = mean[2] + X[(996, 2)]
# mean[3] = mean[3] + X[(996, 3)]
# mean[4] = mean[4] + X[(996, 4)]
# mean[5] = mean[5] + X[(996, 5)]
# mean[6] = mean[6] + X[(996, 6)]
# mean[7] = mean[7] + X[(996, 7)]
# mean[8] = mean[8] + X[(996, 8)]
# mean[9] = mean[9] + X[(996, 9)]
# mean[10] = mean[10] + X[(996, 10)]
# mean[11] = mean[11] + X[(996, 11)]
# mean[12] = mean[12] + X[(996, 12)]
# mean[13] = mean[13] + X[(996, 13)]
# mean[14] = mean[14] + X[(996, 14)]
# mean[15] = mean[15] + X[(996, 15)]
# mean[16] = mean[16] + X[(996, 16)]
# mean[17] = mean[17] + X[(996, 17)]
# mean[18] = mean[18] + X[(996, 18)]
# mean[19] = mean[19] + X[(996, 19)]
# mean[0] = mean[0] + X[(997, 0)]
# mean[1] = mean[1] + X[(997, 1)]
# mean[2] = mean[2] + X[(997, 2)]
# mean[3] = mean[3] + X[(997, 3)]
# mean[4] = mean[4] + X[(997, 4)]
# mean[5] = mean[5] + X[(997, 5)]
# mean[6] = mean[6] + X[(997, 6)]
# mean[7] = mean[7] + X[(997, 7)]
# mean[8] = mean[8] + X[(997, 8)]
# mean[9] = mean[9] + X[(997, 9)]
# mean[10] = mean[10] + X[(997, 10)]
# mean[11] = mean[11] + X[(997, 11)]
# mean[12] = mean[12] + X[(997, 12)]
# mean[13] = mean[13] + X[(997, 13)]
# mean[14] = mean[14] + X[(997, 14)]
# mean[15] = mean[15] + X[(997, 15)]
# mean[16] = mean[16] + X[(997, 16)]
# mean[17] = mean[17] + X[(997, 17)]
# mean[18] = mean[18] + X[(997, 18)]
# mean[19] = mean[19] + X[(997, 19)]
# mean[0] = mean[0] + X[(998, 0)]
# mean[1] = mean[1] + X[(998, 1)]
# mean[2] = mean[2] + X[(998, 2)]
# mean[3] = mean[3] + X[(998, 3)]
# mean[4] = mean[4] + X[(998, 4)]
# mean[5] = mean[5] + X[(998, 5)]
# mean[6] = mean[6] + X[(998, 6)]
# mean[7] = mean[7] + X[(998, 7)]
# mean[8] = mean[8] + X[(998, 8)]
# mean[9] = mean[9] + X[(998, 9)]
# mean[10] = mean[10] + X[(998, 10)]
# mean[11] = mean[11] + X[(998, 11)]
# mean[12] = mean[12] + X[(998, 12)]
# mean[13] = mean[13] + X[(998, 13)]
# mean[14] = mean[14] + X[(998, 14)]
# mean[15] = mean[15] + X[(998, 15)]
# mean[16] = mean[16] + X[(998, 16)]
# mean[17] = mean[17] + X[(998, 17)]
# mean[18] = mean[18] + X[(998, 18)]
# mean[19] = mean[19] + X[(998, 19)]
# mean[0] = mean[0] + X[(999, 0)]
# mean[1] = mean[1] + X[(999, 1)]
# mean[2] = mean[2] + X[(999, 2)]
# mean[3] = mean[3] + X[(999, 3)]
# mean[4] = mean[4] + X[(999, 4)]
# mean[5] = mean[5] + X[(999, 5)]
# mean[6] = mean[6] + X[(999, 6)]
# mean[7] = mean[7] + X[(999, 7)]
# mean[8] = mean[8] + X[(999, 8)]
# mean[9] = mean[9] + X[(999, 9)]
# mean[10] = mean[10] + X[(999, 10)]
# mean[11] = mean[11] + X[(999, 11)]
# mean[12] = mean[12] + X[(999, 12)]
# mean[13] = mean[13] + X[(999, 13)]
# mean[14] = mean[14] + X[(999, 14)]
# mean[15] = mean[15] + X[(999, 15)]
# mean[16] = mean[16] + X[(999, 16)]
# mean[17] = mean[17] + X[(999, 17)]
# mean[18] = mean[18] + X[(999, 18)]
# mean[19] = mean[19] + X[(999, 19)]
# CPU times: user 1.7 s, sys: 952 ms, total: 2.65 s
# Wall time: 1.77 s
# CPU times: user 70 µs, sys: 24 µs, total: 94 µs
# Wall time: 97.5 µs

# %%
# Benchmarking time for computing covariance
# %time cov_naive(X)
# %time cov(X)
pass
# Out:
# CPU times: user 497 µs, sys: 171 µs, total: 668 µs
# Wall time: 388 µs
# CPU times: user 919 µs, sys: 0 ns, total: 919 µs
# Wall time: 526 µs

# %% [markdown]
# ## 2. Affine Transformation of Dataset
# In this week we are also going to verify a few properties about the mean and
# covariance of affine transformation of random variables.
#
# Consider a data matrix $X$ of size (N, D). We would like to know
# what is the covariance when we apply affine transformation $Ax_i + b$ for each datapoint $x_i$ in $X$. i.e.
# we would like to know what happens to the mean and covariance for the new dataset if we apply affine transformation.

# %%
# GRADED FUNCTION: DO NOT EDIT THIS LINE

def affine_mean(mean, A, b):
    """Compute the mean after affine transformation
    Args:
        mean: `ndarray` of shape (D,), the sample mean vector for some dataset.
        A, b: `ndarray` of shape (D, D) and (D,), affine transformation applied to x
    Returns:
        sample mean vector of shape (D,) after affine transformation.
    """
    # YOUR CODE HERE
    ### Uncomment and edit the code below
    ### Edit the code below to compute the mean vector after affine transformation
    affine_m = A @ mean + b
    ### Update affine_m
  
    ###
    return affine_m

# %%
# GRADED FUNCTION: DO NOT EDIT THIS LINE
def affine_covariance(S, A, b):
    """Compute the covariance matrix after affine transformation
    
    Args:
        mean: `ndarray` of shape (D,), the sample covariance matrix for some dataset.
        A, b: `ndarray` of shape (D, D) and (D,), affine transformation applied to x
    
    Returns:
        sample covariance matrix of shape (D, D) after the transformation
    """
    # YOUR CODE HERE
    ### Uncomment and edit the code below
    ### EDIT the code below to compute the covariance matrix after affine transformation
    affine_cov = A @ S @ A.T
    ### Update affine_cov
  
    ###
    return affine_cov

# %%
from numpy.testing import assert_allclose

A = np.array([[0, 1], [2, 3]])
b = np.ones(2)
m = np.full((2,), 2)
S = np.eye(2)*2

expected_affine_mean = np.array([ 3., 11.])
expected_affine_cov = np.array(
    [[ 2.,  6.],
    [ 6., 26.]])

assert_allclose(affine_mean(m, A, b), expected_affine_mean, rtol=1e-4)
### Some hidden tests below
### ...

# %%
from numpy.testing import assert_allclose

A = np.array([[0, 1], [2, 3]])
b = np.ones(2)
m = np.full((2,), 2)
S = np.eye(2)*2

expected_affine_cov = np.array(
    [[ 2.,  6.],
    [ 6., 26.]])

assert_allclose(affine_covariance(S, A, b), 
                expected_affine_cov, rtol=1e-4)

### Some hidden tests below
### ...

# %% [markdown]
# Once the two functions above are implemented, we can verify the correctness our implementation. Assuming that we have some $A$ and $b$.

# %%
random = np.random.RandomState(42)
A = random.randn(4,4)
b = random.randn(4)

print(A)
print(b)
# Out:
# [[ 0.49671415 -0.1382643   0.64768854  1.52302986]
#  [-0.23415337 -0.23413696  1.57921282  0.76743473]
#  [-0.46947439  0.54256004 -0.46341769 -0.46572975]
#  [ 0.24196227 -1.91328024 -1.72491783 -0.56228753]]
# [-1.01283112  0.31424733 -0.90802408 -1.4123037 ]

# %% [markdown]
# Next we can generate some random dataset $X$

# %%
X = random.randn(100, 4)

# %% [markdown]
# Assuming that for some dataset $X$, the mean and covariance are $m$, $S$, and for the new dataset after affine transformation $X'$, the mean and covariance are $m'$ and $S'$, then we would have the following identity:
#
# $$m' = \text{affine_mean}(m, A, b)$$
#
# $$S' = \text{affine_covariance}(S, A, b)$$

# %%
X1 = ((A @ (X.T)).T + b)  # applying affine transformation once
X2 = ((A @ (X1.T)).T + b) # twice

# %% [markdown]
# One very useful way to compare whether arrays are equal/similar is use the helper functions
# in `numpy.testing`.
#
# Check the Numpy [documentation](https://docs.scipy.org/doc/numpy-1.13.0/reference/routines.testing.html)
# for details.
#
# If you are interested in learning more about floating point arithmetic, here is a good [paper](http://citeseerx.ist.psu.edu/viewdoc/summary?doi=10.1.1.22.6768).

# %%
print(np.testing.assert_allclose(mean(X1), affine_mean(mean(X), A, b)) == np.testing.assert_allclose(cov(X1),  affine_covariance(cov(X), A, b)))
# Out:
# True

# %%
np.testing.assert_allclose(mean(X1), affine_mean(mean(X), A, b))
np.testing.assert_allclose(cov(X1),  affine_covariance(cov(X), A, b))

# %%
np.testing.assert_allclose(mean(X2), affine_mean(mean(X1), A, b))
np.testing.assert_allclose(cov(X2),  affine_covariance(cov(X1), A, b))
